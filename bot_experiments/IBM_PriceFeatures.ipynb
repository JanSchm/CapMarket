# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
print('Tensorflow version: {}'.format(tf.__version__))

import matplotlib.pyplot as plt
plt.style.use('seaborn')

import warnings
warnings.filterwarnings('ignore')
# Out:
# Tensorflow version: 2.2.0

# %% [markdown]
# ## Hyperparameters

# %%
seq_len = 128

# %% [markdown]
# ## Load IBM price and volume data

# %%
IBM_path = '/content/drive/My Drive/Capital_Market/Tutorials/Medium-Part1: The beginning of an autonomous trading bot/19620102_20200508_IBM_Prices.csv'

df = pd.read_csv(IBM_path, delimiter=',', usecols=['Date', 'Open', 'High', 'Low', 'Close', 'Volume'])

# Replace 0 to avoid dividing by 0 later on
df['Volume'].replace(to_replace=0, method='ffill', inplace=True) 
df.sort_values('Date', inplace=True)
df.head()
# Out:
#          Date      Open      High       Low     Close  Volume
# 0  1962-01-02  7.713333  7.713333  7.626667  7.626667  387200
# 1  1962-01-03  7.626667  7.693333  7.626667  7.693333  288000
# 2  1962-01-04  7.693333  7.693333  7.613333  7.616667  256000
# 3  1962-01-05  7.606667  7.606667  7.453333  7.466667  363200
# 4  1962-01-08  7.460000  7.460000  7.266667  7.326667  544000

# %% [markdown]
# ## Plot daily IBM closing prices

# %%
plt.figure(figsize=(15, 5))
plt.plot(df['Close'])
plt.xticks(range(0, df.shape[0], 1464), df['Date'].loc[::1464], rotation=0)
plt.ylabel('Price', fontsize=18)
plt.title("Close Price", fontsize=20)
plt.legend(['Close Price'], fontsize='x-large', loc='best')
plt.show()

# %% [markdown]
# ## Plot daily IBM volumes

# %%
plt.figure(figsize=(15, 5))
plt.plot(df['Volume'])
plt.xticks(range(0, df.shape[0], 1464), df['Date'].loc[::1464], rotation=0)
plt.ylabel('Volume', fontsize=18)
plt.title("Volume", fontsize=20)
plt.legend(['Volume'], fontsize='x-large', loc='best')
plt.show()

# %% [markdown]
# ## Calculate normalized percentage change for all columns

# %%
'''Calculate percentage change'''

df['Open'] = df['Open'].pct_change() # Create arithmetic returns column
df['High'] = df['High'].pct_change() # Create arithmetic returns column
df['Low'] = df['Low'].pct_change() # Create arithmetic returns column
df['Close'] = df['Close'].pct_change() # Create arithmetic returns column
df['Volume'] = df['Volume'].pct_change()

df.dropna(how='any', axis=0, inplace=True) # Drop all rows with NaN values

###############################################################################
'''Normalize price columns'''

min_return = min(df[['Open', 'High', 'Low', 'Close']].min(axis=0))
max_return = max(df[['Open', 'High', 'Low', 'Close']].max(axis=0))

# Min-max normalize price columns (0-1 range)
df['Open'] = (df['Open'] - min_return) / (max_return - min_return)
df['High'] = (df['High'] - min_return) / (max_return - min_return)
df['Low'] = (df['Low'] - min_return) / (max_return - min_return)
df['Close'] = (df['Close'] - min_return) / (max_return - min_return)

###############################################################################
'''Normalize volume column'''

min_volume = df['Volume'].min(axis=0)
max_volume = df['Volume'].max(axis=0)

# Min-max normalize volume columns (0-1 range)
df['Volume'] = (df['Volume'] - min_volume) / (max_volume - min_volume)

###############################################################################
'''Create training, validation and test split'''

times = sorted(df.index.values)
last_10pct = sorted(df.index.values)[-int(0.1*len(times))] # Last 10% of series
last_20pct = sorted(df.index.values)[-int(0.2*len(times))] # Last 20% of series

df_train = df[(df.index < last_20pct)]  # Training data are 80% of total data
df_val = df[(df.index >= last_20pct) & (df.index < last_10pct)]
df_test = df[(df.index >= last_10pct)]

# Remove date column
df_train.drop(columns=['Date'], inplace=True)
df_val.drop(columns=['Date'], inplace=True)
df_test.drop(columns=['Date'], inplace=True)

# Convert pandas columns into arrays
train_data = df_train.values
val_data = df_val.values
test_data = df_test.values
print('Training data shape: {}'.format(train_data.shape))
print('Validation data shape: {}'.format(val_data.shape))
print('Test data shape: {}'.format(test_data.shape))

df_train.head()
# Out:
# Training data shape: (11750, 5)
# Validation data shape: (1469, 5)
# Test data shape: (1468, 5)
#        Open      High       Low     Close    Volume
# 1  0.564779  0.585893  0.592227  0.613581  0.026212
# 2  0.613581  0.592227  0.587956  0.567883  0.031593
# 3  0.564707  0.564707  0.540887  0.544117  0.051245
# 4  0.545124  0.545124  0.531045  0.546422  0.054177
# 5  0.559480  0.607509  0.623604  0.621124  0.032115

# %% [markdown]
# ## Plot daily changes of close prices and volume

# %%
fig = plt.figure(figsize=(15,10))
st = fig.suptitle("Data Separation", fontsize=20)
st.set_y(0.92)

###############################################################################

ax1 = fig.add_subplot(211)
ax1.plot(np.arange(train_data.shape[0]), df_train['Close'], label='Training data')

ax1.plot(np.arange(train_data.shape[0], 
                   train_data.shape[0]+val_data.shape[0]), df_val['Close'], label='Validation data')

ax1.plot(np.arange(train_data.shape[0]+val_data.shape[0], 
                   train_data.shape[0]+val_data.shape[0]+test_data.shape[0]), df_test['Close'], label='Test data')
ax1.set_xlabel('Date')
ax1.set_ylabel('Normalized Closing Returns')

###############################################################################

ax2 = fig.add_subplot(212)
ax2.plot(np.arange(train_data.shape[0]), df_train['Volume'], label='Training data')

ax2.plot(np.arange(train_data.shape[0], 
                   train_data.shape[0]+val_data.shape[0]), df_val['Volume'], label='Validation data')

ax2.plot(np.arange(train_data.shape[0]+val_data.shape[0], 
                   train_data.shape[0]+val_data.shape[0]+test_data.shape[0]), df_test['Volume'], label='Test data')
ax2.set_xlabel('Date')
ax2.set_ylabel('Normalized Volume Changes')

plt.legend(loc='best')

# %% [markdown]
# ## Create chunks of training, validation and test data

# %%
# Training data
X_train, y_train = [], []
for i in range(seq_len, len(train_data)):
  X_train.append(train_data[i-seq_len:i]) # Chunks of training data with a length of 128 df-rows
  y_train.append(train_data[:, 3][i]) #Value of 4th column (Close Price) of df-row 128+1
X_train, y_train = np.array(X_train), np.array(y_train)

###############################################################################

# Validation data
X_val, y_val = [], []
for i in range(seq_len, len(val_data)):
    X_val.append(val_data[i-seq_len:i])
    y_val.append(val_data[:, 3][i])
X_val, y_val = np.array(X_val), np.array(y_val)

###############################################################################

# Test data
X_test, y_test = [], []
for i in range(seq_len, len(test_data)):
    X_test.append(test_data[i-seq_len:i])
    y_test.append(test_data[:, 3][i])    
X_test, y_test = np.array(X_test), np.array(y_test)

print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
# Out:
# (11622, 128, 5) (11622,)
# (1341, 128, 5) (1341,)

# %% [markdown]
# ## 1D Convolution layers for a CNN+LSTM model

# %%
def Inception_A(layer_in, c7):
  branch1x1_1 = Conv1D(c7, kernel_size=1, padding="same", use_bias=False)(layer_in)
  branch1x1 = BatchNormalization()(branch1x1_1)
  branch1x1 = ReLU()(branch1x1)
  
  branch5x5_1 = Conv1D(c7, kernel_size=1, padding='same', use_bias=False)(layer_in)
  branch5x5 = BatchNormalization()(branch5x5_1)
  branch5x5 = ReLU()(branch5x5)
  branch5x5 = Conv1D(c7, kernel_size=5, padding='same', use_bias=False)(branch5x5)
  branch5x5 = BatchNormalization()(branch5x5)
  branch5x5 = ReLU()(branch5x5)  
  
  branch3x3_1 = Conv1D(c7, kernel_size=1, padding='same', use_bias=False)(layer_in)
  branch3x3 = BatchNormalization()(branch3x3_1)
  branch3x3 = ReLU()(branch3x3)
  branch3x3 = Conv1D(c7, kernel_size=3, padding='same', use_bias=False)(branch3x3)
  branch3x3 = BatchNormalization()(branch3x3)
  branch3x3 = ReLU()(branch3x3)
  branch3x3 = Conv1D(c7, kernel_size=3, padding='same', use_bias=False)(branch3x3)
  branch3x3 = BatchNormalization()(branch3x3)
  branch3x3 = ReLU()(branch3x3) 
  
  branch_pool = AveragePooling1D(pool_size=(3), strides=1, padding='same')(layer_in)
  branch_pool = Conv1D(c7, kernel_size=1, padding='same', use_bias=False)(branch_pool)
  branch_pool = BatchNormalization()(branch_pool)
  branch_pool = ReLU()(branch_pool)
  outputs = Concatenate(axis=-1)([branch1x1, branch5x5, branch3x3, branch_pool])
  return outputs


def Inception_B(layer_in, c7):
  branch3x3 = Conv1D(c7, kernel_size=3, padding="same", strides=2, use_bias=False)(layer_in)
  branch3x3 = BatchNormalization()(branch3x3)
  branch3x3 = ReLU()(branch3x3)  
  
  branch3x3dbl = Conv1D(c7, kernel_size=1, padding="same", use_bias=False)(layer_in)
  branch3x3dbl = BatchNormalization()(branch3x3dbl)
  branch3x3dbl = ReLU()(branch3x3dbl)  
  branch3x3dbl = Conv1D(c7, kernel_size=3, padding="same", use_bias=False)(branch3x3dbl)  
  branch3x3dbl = BatchNormalization()(branch3x3dbl)
  branch3x3dbl = ReLU()(branch3x3dbl)  
  branch3x3dbl = Conv1D(c7, kernel_size=3, padding="same", strides=2, use_bias=False)(branch3x3dbl)    
  branch3x3dbl = BatchNormalization()(branch3x3dbl)
  branch3x3dbl = ReLU()(branch3x3dbl)   
  
  branch_pool = MaxPooling1D(pool_size=3, strides=2, padding="same")(layer_in)
  
  outputs = Concatenate(axis=-1)([branch3x3, branch3x3dbl, branch_pool])
  return outputs


def Inception_C(layer_in, c7):
  branch1x1_1 = Conv1D(c7, kernel_size=1, padding="same", use_bias=False)(layer_in)
  branch1x1 = BatchNormalization()(branch1x1_1)
  branch1x1 = ReLU()(branch1x1)   
  
  branch7x7_1 = Conv1D(c7, kernel_size=1, padding="same", use_bias=False)(layer_in)
  branch7x7 = BatchNormalization()(branch7x7_1)
  branch7x7 = ReLU()(branch7x7)   
  branch7x7 = Conv1D(c7, kernel_size=(7), padding="same", use_bias=False)(branch7x7)
  branch7x7 = BatchNormalization()(branch7x7)
  branch7x7 = ReLU()(branch7x7)  
  branch7x7 = Conv1D(c7, kernel_size=(1), padding="same", use_bias=False)(branch7x7)  
  branch7x7 = BatchNormalization()(branch7x7)
  branch7x7 = ReLU()(branch7x7)   

  branch7x7dbl_1 = Conv1D(c7, kernel_size=1, padding="same", use_bias=False)(layer_in)  
  branch7x7dbl = BatchNormalization()(branch7x7dbl_1)
  branch7x7dbl = ReLU()(branch7x7dbl)  
  branch7x7dbl = Conv1D(c7, kernel_size=(7), padding="same", use_bias=False)(branch7x7dbl)  
  branch7x7dbl = BatchNormalization()(branch7x7dbl)
  branch7x7dbl = ReLU()(branch7x7dbl) 
  branch7x7dbl = Conv1D(c7, kernel_size=(1), padding="same", use_bias=False)(branch7x7dbl)  
  branch7x7dbl = BatchNormalization()(branch7x7dbl)
  branch7x7dbl = ReLU()(branch7x7dbl)  
  branch7x7dbl = Conv1D(c7, kernel_size=(7), padding="same", use_bias=False)(branch7x7dbl)  
  branch7x7dbl = BatchNormalization()(branch7x7dbl)
  branch7x7dbl = ReLU()(branch7x7dbl)  
  branch7x7dbl = Conv1D(c7, kernel_size=(1), padding="same", use_bias=False)(branch7x7dbl)  
  branch7x7dbl = BatchNormalization()(branch7x7dbl)
  branch7x7dbl = ReLU()(branch7x7dbl)  
  
  branch_pool = AveragePooling1D(pool_size=3, strides=1, padding='same')(layer_in)
  branch_pool = Conv1D(c7, kernel_size=1, padding='same', use_bias=False)(branch_pool)
  branch_pool = BatchNormalization()(branch_pool)
  branch_pool = ReLU()(branch_pool)  
  
  outputs = Concatenate(axis=-1)([branch1x1, branch7x7, branch7x7dbl, branch_pool])
  return outputs

# %% [markdown]
# # **Testing different model architectures**

# %% [markdown]
# ### Bi-LSTM model

# %%
def create_model():
  in_seq = Input(shape = (seq_len, 5))
      
  x = Bidirectional(LSTM(128, return_sequences=True))(in_seq)
  x = Bidirectional(LSTM(128, return_sequences=True))(x)
  x = Bidirectional(LSTM(64, return_sequences=True))(x) 
          
  avg_pool = GlobalAveragePooling1D()(x)
  max_pool = GlobalMaxPooling1D()(x)
  conc = concatenate([avg_pool, max_pool])
  conc = Dense(64, activation="relu")(conc)
  out = Dense(1, activation="linear")(conc)      

  model = Model(inputs=in_seq, outputs=out)
  model.compile(loss="mse", optimizer="adam", metrics=['mae', 'mape'])    
  return model

model = create_model()

#model.summary()
#callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=2)
callback = tf.keras.callbacks.ModelCheckpoint('Bi-LSTM.hdf5', monitor='val_loss', save_best_only=True, verbose=1)

model.fit(X_train, y_train,
              batch_size=2048,
              verbose=2,
              callbacks=[callback],
              epochs=200,
              #shuffle=True,
              validation_data=(X_val, y_val),)    

model = tf.keras.models.load_model('/content/Bi-LSTM.hdf5')

###############################################################################
'''Calculate predictions and metrics'''

#Calculate predication for training, validation and test data
train_pred = model.predict(X_train)
val_pred = model.predict(X_val)
test_pred = model.predict(X_test)

#Print evaluation metrics for all datasets
train_eval = model.evaluate(X_train, y_train, verbose=0)
val_eval = model.evaluate(X_val, y_val, verbose=0)
test_eval = model.evaluate(X_test, y_test, verbose=0)
print(' ')
print('Evaluation metrics')
print('Training Data - Loss: {:.4f}, MAE: {:.4f}, MAPE: {:.4f}'.format(train_eval[0], train_eval[1], train_eval[2]))
print('Validation Data - Loss: {:.4f}, MAE: {:.4f}, MAPE: {:.4f}'.format(val_eval[0], val_eval[1], val_eval[2]))
print('Test Data - Loss: {:.4f}, MAE: {:.4f}, MAPE: {:.4f}'.format(test_eval[0], test_eval[1], test_eval[2]))

###############################################################################
'''Display results'''

fig = plt.figure(figsize=(15,15))
st = fig.suptitle("Bi-LSTM Model", fontsize=22)
st.set_y(1.02)

#Plot training data results
ax11 = fig.add_subplot(311)
ax11.plot(train_data[:, 3], label='IBM Closing Returns')
ax11.plot(train_pred, color='yellow', linewidth=3, label='Predicted IBM Closing Returns')
ax11.set_title("Training Data", fontsize=18)
ax11.set_xlabel('Date')
ax11.set_ylabel('IBM Closing Returns')

#Plot validation data results
ax21 = fig.add_subplot(312)
ax21.plot(val_data[:, 3], label='IBM Closing Returns')
ax21.plot(val_pred, color='yellow', linewidth=3, label='Predicted IBM Closing Returns')
ax21.set_title("Validation Data", fontsize=18)
ax21.set_xlabel('Date')
ax21.set_ylabel('IBM Closing Returns')

#Plot test data results
ax31 = fig.add_subplot(313)
ax31.plot(test_data[:, 3], label='IBM Closing Returns')
ax31.plot(test_pred, color='yellow', linewidth=3, label='Predicted IBM Closing Returns')
ax31.set_title("Test Data", fontsize=18)
ax31.set_xlabel('Date')
ax31.set_ylabel('IBM Closing Returns')

plt.tight_layout()
plt.legend(loc='best')
# Out:
# Epoch 1/200
#
# Epoch 00001: val_loss improved from inf to 0.00348, saving model to Bi-LSTM.hdf5
# 6/6 - 8s - loss: 0.0898 - mae: 0.2451 - mape: 41.5593 - val_loss: 0.0035 - val_mae: 0.0530 - val_mape: 8.7714
# Epoch 2/200
#
# Epoch 00002: val_loss did not improve from 0.00348
# 6/6 - 6s - loss: 0.0096 - mae: 0.0844 - mape: 14.5968 - val_loss: 0.0079 - val_mae: 0.0845 - val_mape: 14.0454
# Epoch 3/200
#
# Epoch 00003: val_loss improved from 0.00348 to 0.00209, saving model to Bi-LSTM.hdf5
# 6/6 - 6s - loss: 0.0050 - mae: 0.0591 - mape: 10.4103 - val_loss: 0.0021 - val_mae: 0.0385 - val_mape: 6.3608
# Epoch 4/200
#
# Epoch 00004: val_loss did not improve from 0.00209
# 6/6 - 6s - loss: 0.0033 - mae: 0.0462 - mape: 7.9557 - val_loss: 0.0030 - val_mae: 0.0487 - val_mape: 8.4232
# Epoch 5/200
#
# Epoch 00005: val_loss improved from 0.00209 to 0.00100, saving model to Bi-LSTM.hdf5
# 6/6 - 6s - loss: 0.0025 - mae: 0.0390 - mape: 6.8809 - val_loss: 9.9614e-04 - val_mae: 0.0230 - val_mape: 3.8356
# Epoch 6/200
#
# Epoch 00006: val_loss did not improve from 0.00100
# 6/6 - 6s - loss: 0.0019 - mae: 0.0325 - mape: 5.8946 - val_loss: 0.0012 - val_mae: 0.0266 - val_mape: 4.4086
# Epoch 7/200
#
# Epoch 00007: val_loss did not improve from 0.00100
# 6/6 - 6s - loss: 0.0018 - mae: 0.0310 - mape: 5.5047 - val_loss: 0.0011 - val_mae: 0.0253 - val_mape: 4.3772
# Epoch 8/200
#
# Epoch 00008: val_loss improved from 0.00100 to 0.00087, saving model to Bi-LSTM.hdf5
# 6/6 - 6s - loss: 0.0017 - mae: 0.0293 - mape: 5.2275 - val_loss: 8.7057e-04 - val_mae: 0.0211 - val_mape: 3.5859
# Epoch 9/200
#
# Epoch 00009: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0285 - mape: 5.1671 - val_loss: 9.7006e-04 - val_mae: 0.0225 - val_mape: 3.7706
# Epoch 10/200
#
# Epoch 00010: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0282 - mape: 5.0591 - val_loss: 8.7267e-04 - val_mae: 0.0212 - val_mape: 3.6129
# Epoch 11/200
#
# Epoch 00011: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0279 - mape: 5.0005 - val_loss: 8.9478e-04 - val_mae: 0.0216 - val_mape: 3.7096
# Epoch 12/200
#
# Epoch 00012: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0280 - mape: 5.0358 - val_loss: 8.7662e-04 - val_mae: 0.0211 - val_mape: 3.5806
# Epoch 13/200
#
# Epoch 00013: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0279 - mape: 5.0392 - val_loss: 9.1569e-04 - val_mae: 0.0217 - val_mape: 3.6464
# Epoch 14/200
#
# Epoch 00014: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0279 - mape: 5.0336 - val_loss: 8.7190e-04 - val_mae: 0.0211 - val_mape: 3.5815
# Epoch 15/200
#
# Epoch 00015: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0278 - mape: 4.9968 - val_loss: 8.7320e-04 - val_mae: 0.0212 - val_mape: 3.6162
# Epoch 16/200
#
# Epoch 00016: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9874 - val_loss: 8.7120e-04 - val_mae: 0.0212 - val_mape: 3.6027
# Epoch 17/200
#
# Epoch 00017: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9857 - val_loss: 8.7204e-04 - val_mae: 0.0212 - val_mape: 3.6091
# Epoch 18/200
#
# Epoch 00018: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9965 - val_loss: 8.7703e-04 - val_mae: 0.0212 - val_mape: 3.5807
# Epoch 19/200
#
# Epoch 00019: val_loss improved from 0.00087 to 0.00087, saving model to Bi-LSTM.hdf5
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9852 - val_loss: 8.7027e-04 - val_mae: 0.0211 - val_mape: 3.5923
# Epoch 20/200
#
# Epoch 00020: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9838 - val_loss: 8.7087e-04 - val_mae: 0.0211 - val_mape: 3.6002
# Epoch 21/200
#
# Epoch 00021: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9855 - val_loss: 8.7207e-04 - val_mae: 0.0212 - val_mape: 3.6096
# Epoch 22/200
#
# Epoch 00022: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9974 - val_loss: 8.7117e-04 - val_mae: 0.0211 - val_mape: 3.5823
# Epoch 23/200
#
# Epoch 00023: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9871 - val_loss: 8.7086e-04 - val_mae: 0.0211 - val_mape: 3.5830
# Epoch 24/200
#
# Epoch 00024: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0278 - mape: 5.0024 - val_loss: 8.7132e-04 - val_mae: 0.0211 - val_mape: 3.5819
# Epoch 25/200
#
# Epoch 00025: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0278 - mape: 5.0116 - val_loss: 8.7073e-04 - val_mae: 0.0211 - val_mape: 3.5833
# Epoch 26/200
#
# Epoch 00026: val_loss improved from 0.00087 to 0.00087, saving model to Bi-LSTM.hdf5
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9918 - val_loss: 8.7015e-04 - val_mae: 0.0211 - val_mape: 3.5921
# Epoch 27/200
#
# Epoch 00027: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9953 - val_loss: 8.8205e-04 - val_mae: 0.0212 - val_mape: 3.5863
# Epoch 28/200
#
# Epoch 00028: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9975 - val_loss: 8.7598e-04 - val_mae: 0.0211 - val_mape: 3.5801
# Epoch 29/200
#
# Epoch 00029: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9946 - val_loss: 8.7763e-04 - val_mae: 0.0212 - val_mape: 3.5810
# Epoch 30/200
#
# Epoch 00030: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9921 - val_loss: 8.7394e-04 - val_mae: 0.0211 - val_mape: 3.5798
# Epoch 31/200
#
# Epoch 00031: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9831 - val_loss: 8.7110e-04 - val_mae: 0.0211 - val_mape: 3.5818
# Epoch 32/200
#
# Epoch 00032: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9880 - val_loss: 8.7398e-04 - val_mae: 0.0211 - val_mape: 3.5797
# Epoch 33/200
#
# Epoch 00033: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9928 - val_loss: 8.7352e-04 - val_mae: 0.0211 - val_mape: 3.5798
# Epoch 34/200
#
# Epoch 00034: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9893 - val_loss: 8.7999e-04 - val_mae: 0.0212 - val_mape: 3.5836
# Epoch 35/200
#
# Epoch 00035: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9954 - val_loss: 8.8312e-04 - val_mae: 0.0212 - val_mape: 3.5879
# Epoch 36/200
#
# Epoch 00036: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0278 - mape: 5.0037 - val_loss: 8.7699e-04 - val_mae: 0.0212 - val_mape: 3.5804
# Epoch 37/200
#
# Epoch 00037: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9960 - val_loss: 8.7452e-04 - val_mae: 0.0211 - val_mape: 3.5795
# Epoch 38/200
#
# Epoch 00038: val_loss improved from 0.00087 to 0.00087, saving model to Bi-LSTM.hdf5
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9893 - val_loss: 8.7000e-04 - val_mae: 0.0211 - val_mape: 3.5856
# Epoch 39/200
#
# Epoch 00039: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9904 - val_loss: 8.7874e-04 - val_mae: 0.0213 - val_mape: 3.6451
# Epoch 40/200
#
# Epoch 00040: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0278 - mape: 5.0041 - val_loss: 9.0284e-04 - val_mae: 0.0218 - val_mape: 3.7398
# Epoch 41/200
#
# Epoch 00041: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0280 - mape: 5.0386 - val_loss: 8.8490e-04 - val_mae: 0.0215 - val_mape: 3.6716
# Epoch 42/200
#
# Epoch 00042: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0278 - mape: 5.0172 - val_loss: 8.8215e-04 - val_mae: 0.0214 - val_mape: 3.6601
# Epoch 43/200
#
# Epoch 00043: val_loss improved from 0.00087 to 0.00087, saving model to Bi-LSTM.hdf5
# 6/6 - 6s - loss: 0.0016 - mae: 0.0278 - mape: 5.0151 - val_loss: 8.6985e-04 - val_mae: 0.0211 - val_mape: 3.5921
# Epoch 44/200
#
# Epoch 00044: val_loss improved from 0.00087 to 0.00087, saving model to Bi-LSTM.hdf5
# 6/6 - 6s - loss: 0.0016 - mae: 0.0278 - mape: 5.0008 - val_loss: 8.6984e-04 - val_mae: 0.0211 - val_mape: 3.5919
# Epoch 45/200
#
# Epoch 00045: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0279 - mape: 5.0293 - val_loss: 8.7904e-04 - val_mae: 0.0212 - val_mape: 3.5824
# Epoch 46/200
#
# Epoch 00046: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0278 - mape: 5.0007 - val_loss: 9.0490e-04 - val_mae: 0.0215 - val_mape: 3.6257
# Epoch 47/200
#
# Epoch 00047: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0280 - mape: 5.0277 - val_loss: 8.8460e-04 - val_mae: 0.0213 - val_mape: 3.5900
# Epoch 48/200
#
# Epoch 00048: val_loss improved from 0.00087 to 0.00087, saving model to Bi-LSTM.hdf5
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9873 - val_loss: 8.6972e-04 - val_mae: 0.0211 - val_mape: 3.5882
# Epoch 49/200
#
# Epoch 00049: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9863 - val_loss: 8.7197e-04 - val_mae: 0.0212 - val_mape: 3.6113
# Epoch 50/200
#
# Epoch 00050: val_loss improved from 0.00087 to 0.00087, saving model to Bi-LSTM.hdf5
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9895 - val_loss: 8.6970e-04 - val_mae: 0.0211 - val_mape: 3.5909
# Epoch 51/200
#
# Epoch 00051: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9848 - val_loss: 8.6983e-04 - val_mae: 0.0211 - val_mape: 3.5936
# Epoch 52/200
#
# Epoch 00052: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9956 - val_loss: 8.7966e-04 - val_mae: 0.0212 - val_mape: 3.5832
# Epoch 53/200
#
# Epoch 00053: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0278 - mape: 4.9969 - val_loss: 8.8175e-04 - val_mae: 0.0212 - val_mape: 3.5861
# Epoch 54/200
#
# Epoch 00054: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0278 - mape: 5.0007 - val_loss: 8.9620e-04 - val_mae: 0.0214 - val_mape: 3.6094
# Epoch 55/200
#
# Epoch 00055: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0278 - mape: 5.0082 - val_loss: 8.7706e-04 - val_mae: 0.0212 - val_mape: 3.5803
# Epoch 56/200
#
# Epoch 00056: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0278 - mape: 5.0052 - val_loss: 8.6982e-04 - val_mae: 0.0211 - val_mape: 3.5941
# Epoch 57/200
#
# Epoch 00057: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0279 - mape: 5.0259 - val_loss: 8.8791e-04 - val_mae: 0.0215 - val_mape: 3.6843
# Epoch 58/200
#
# Epoch 00058: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0278 - mape: 5.0148 - val_loss: 8.7640e-04 - val_mae: 0.0213 - val_mape: 3.6351
# Epoch 59/200
#
# Epoch 00059: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0279 - mape: 5.0219 - val_loss: 8.8625e-04 - val_mae: 0.0213 - val_mape: 3.5924
# Epoch 60/200
#
# Epoch 00060: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0277 - mape: 4.9889 - val_loss: 8.7307e-04 - val_mae: 0.0211 - val_mape: 3.5792
# Epoch 61/200
#
# Epoch 00061: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9958 - val_loss: 8.7066e-04 - val_mae: 0.0212 - val_mape: 3.6028
# Epoch 62/200
#
# Epoch 00062: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0279 - mape: 5.0269 - val_loss: 8.9728e-04 - val_mae: 0.0214 - val_mape: 3.6115
# Epoch 63/200
#
# Epoch 00063: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0278 - mape: 5.0010 - val_loss: 8.9857e-04 - val_mae: 0.0214 - val_mape: 3.6139
# Epoch 64/200
#
# Epoch 00064: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0278 - mape: 4.9979 - val_loss: 8.7047e-04 - val_mae: 0.0211 - val_mape: 3.6015
# Epoch 65/200
#
# Epoch 00065: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9913 - val_loss: 8.6975e-04 - val_mae: 0.0211 - val_mape: 3.5937
# Epoch 66/200
#
# Epoch 00066: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9910 - val_loss: 8.7192e-04 - val_mae: 0.0211 - val_mape: 3.5798
# Epoch 67/200
#
# Epoch 00067: val_loss improved from 0.00087 to 0.00087, saving model to Bi-LSTM.hdf5
# 6/6 - 6s - loss: 0.0016 - mae: 0.0278 - mape: 4.9972 - val_loss: 8.6963e-04 - val_mae: 0.0211 - val_mape: 3.5853
# Epoch 68/200
#
# Epoch 00068: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9931 - val_loss: 8.7930e-04 - val_mae: 0.0214 - val_mape: 3.6484
# Epoch 69/200
#
# Epoch 00069: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0278 - mape: 5.0105 - val_loss: 8.7321e-04 - val_mae: 0.0211 - val_mape: 3.5793
# Epoch 70/200
#
# Epoch 00070: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0278 - mape: 4.9985 - val_loss: 8.9016e-04 - val_mae: 0.0213 - val_mape: 3.5987
# Epoch 71/200
#
# Epoch 00071: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0279 - mape: 5.0184 - val_loss: 8.8904e-04 - val_mae: 0.0213 - val_mape: 3.5968
# Epoch 72/200
#
# Epoch 00072: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0277 - mape: 4.9928 - val_loss: 8.8212e-04 - val_mae: 0.0214 - val_mape: 3.6606
# Epoch 73/200
#
# Epoch 00073: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0278 - mape: 5.0161 - val_loss: 8.7076e-04 - val_mae: 0.0212 - val_mape: 3.6040
# Epoch 74/200
#
# Epoch 00074: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0278 - mape: 5.0038 - val_loss: 8.8058e-04 - val_mae: 0.0212 - val_mape: 3.5845
# Epoch 75/200
#
# Epoch 00075: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9875 - val_loss: 8.7234e-04 - val_mae: 0.0211 - val_mape: 3.5790
# Epoch 76/200
#
# Epoch 00076: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9807 - val_loss: 8.9912e-04 - val_mae: 0.0217 - val_mape: 3.7268
# Epoch 77/200
#
# Epoch 00077: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0280 - mape: 5.0590 - val_loss: 8.7234e-04 - val_mae: 0.0211 - val_mape: 3.5793
# Epoch 78/200
#
# Epoch 00078: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0278 - mape: 5.0034 - val_loss: 8.8254e-04 - val_mae: 0.0212 - val_mape: 3.5872
# Epoch 79/200
#
# Epoch 00079: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0278 - mape: 5.0089 - val_loss: 8.9050e-04 - val_mae: 0.0216 - val_mape: 3.6947
# Epoch 80/200
#
# Epoch 00080: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0278 - mape: 5.0224 - val_loss: 8.6971e-04 - val_mae: 0.0211 - val_mape: 3.5948
# Epoch 81/200
#
# Epoch 00081: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9886 - val_loss: 8.7582e-04 - val_mae: 0.0211 - val_mape: 3.5796
# Epoch 82/200
#
# Epoch 00082: val_loss improved from 0.00087 to 0.00087, saving model to Bi-LSTM.hdf5
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9833 - val_loss: 8.6949e-04 - val_mae: 0.0211 - val_mape: 3.5912
# Epoch 83/200
#
# Epoch 00083: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9850 - val_loss: 8.7795e-04 - val_mae: 0.0212 - val_mape: 3.5814
# Epoch 84/200
#
# Epoch 00084: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9870 - val_loss: 8.6969e-04 - val_mae: 0.0211 - val_mape: 3.5949
# Epoch 85/200
#
# Epoch 00085: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0276 - mape: 4.9735 - val_loss: 8.9970e-04 - val_mae: 0.0217 - val_mape: 3.7290
# Epoch 86/200
#
# Epoch 00086: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0280 - mape: 5.0521 - val_loss: 8.8680e-04 - val_mae: 0.0213 - val_mape: 3.5934
# Epoch 87/200
#
# Epoch 00087: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0279 - mape: 5.0091 - val_loss: 8.7446e-04 - val_mae: 0.0211 - val_mape: 3.5788
# Epoch 88/200
#
# Epoch 00088: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0278 - mape: 5.0029 - val_loss: 8.7176e-04 - val_mae: 0.0211 - val_mape: 3.5794
# Epoch 89/200
#
# Epoch 00089: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0279 - mape: 5.0273 - val_loss: 8.7522e-04 - val_mae: 0.0213 - val_mape: 3.6301
# Epoch 90/200
#
# Epoch 00090: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0281 - mape: 5.0528 - val_loss: 8.8824e-04 - val_mae: 0.0213 - val_mape: 3.5957
# Epoch 91/200
#
# Epoch 00091: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9889 - val_loss: 8.7032e-04 - val_mae: 0.0211 - val_mape: 3.6017
# Epoch 92/200
#
# Epoch 00092: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9879 - val_loss: 8.7246e-04 - val_mae: 0.0211 - val_mape: 3.5789
# Epoch 93/200
#
# Epoch 00093: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9854 - val_loss: 8.7403e-04 - val_mae: 0.0212 - val_mape: 3.6243
# Epoch 94/200
#
# Epoch 00094: val_loss improved from 0.00087 to 0.00087, saving model to Bi-LSTM.hdf5
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9869 - val_loss: 8.6947e-04 - val_mae: 0.0211 - val_mape: 3.5926
# Epoch 95/200
#
# Epoch 00095: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9959 - val_loss: 8.7214e-04 - val_mae: 0.0212 - val_mape: 3.6142
# Epoch 96/200
#
# Epoch 00096: val_loss improved from 0.00087 to 0.00087, saving model to Bi-LSTM.hdf5
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9876 - val_loss: 8.6944e-04 - val_mae: 0.0211 - val_mape: 3.5930
# Epoch 97/200
#
# Epoch 00097: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9879 - val_loss: 8.7656e-04 - val_mae: 0.0213 - val_mape: 3.6368
# Epoch 98/200
#
# Epoch 00098: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0280 - mape: 5.0487 - val_loss: 9.0421e-04 - val_mae: 0.0215 - val_mape: 3.6249
# Epoch 99/200
#
# Epoch 00099: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0278 - mape: 4.9947 - val_loss: 9.0087e-04 - val_mae: 0.0218 - val_mape: 3.7333
# Epoch 100/200
#
# Epoch 00100: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0278 - mape: 5.0164 - val_loss: 8.6973e-04 - val_mae: 0.0211 - val_mape: 3.5826
# Epoch 101/200
#
# Epoch 00101: val_loss improved from 0.00087 to 0.00087, saving model to Bi-LSTM.hdf5
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9878 - val_loss: 8.6922e-04 - val_mae: 0.0211 - val_mape: 3.5903
# Epoch 102/200
#
# Epoch 00102: val_loss improved from 0.00087 to 0.00087, saving model to Bi-LSTM.hdf5
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9847 - val_loss: 8.6921e-04 - val_mae: 0.0211 - val_mape: 3.5867
# Epoch 103/200
#
# Epoch 00103: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9936 - val_loss: 8.6930e-04 - val_mae: 0.0211 - val_mape: 3.5909
# Epoch 104/200
#
# Epoch 00104: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9901 - val_loss: 8.8088e-04 - val_mae: 0.0212 - val_mape: 3.5853
# Epoch 105/200
#
# Epoch 00105: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0278 - mape: 4.9967 - val_loss: 8.7722e-04 - val_mae: 0.0213 - val_mape: 3.6401
# Epoch 106/200
#
# Epoch 00106: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0278 - mape: 5.0143 - val_loss: 8.7656e-04 - val_mae: 0.0212 - val_mape: 3.5801
# Epoch 107/200
#
# Epoch 00107: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9851 - val_loss: 8.7739e-04 - val_mae: 0.0213 - val_mape: 3.6410
# Epoch 108/200
#
# Epoch 00108: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0278 - mape: 5.0173 - val_loss: 8.7338e-04 - val_mae: 0.0211 - val_mape: 3.5787
# Epoch 109/200
#
# Epoch 00109: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0279 - mape: 5.0158 - val_loss: 9.2142e-04 - val_mae: 0.0221 - val_mape: 3.8043
# Epoch 110/200
#
# Epoch 00110: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0281 - mape: 5.0685 - val_loss: 9.1878e-04 - val_mae: 0.0217 - val_mape: 3.6534
# Epoch 111/200
#
# Epoch 00111: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0280 - mape: 5.0253 - val_loss: 8.9364e-04 - val_mae: 0.0216 - val_mape: 3.7074
# Epoch 112/200
#
# Epoch 00112: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0279 - mape: 5.0350 - val_loss: 8.9309e-04 - val_mae: 0.0214 - val_mape: 3.6041
# Epoch 113/200
#
# Epoch 00113: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0279 - mape: 5.0137 - val_loss: 8.9864e-04 - val_mae: 0.0217 - val_mape: 3.7258
# Epoch 114/200
#
# Epoch 00114: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0280 - mape: 5.0441 - val_loss: 9.0854e-04 - val_mae: 0.0216 - val_mape: 3.6333
# Epoch 115/200
#
# Epoch 00115: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0278 - mape: 5.0044 - val_loss: 8.7120e-04 - val_mae: 0.0212 - val_mape: 3.6093
# Epoch 116/200
#
# Epoch 00116: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0278 - mape: 5.0124 - val_loss: 8.8037e-04 - val_mae: 0.0212 - val_mape: 3.5847
# Epoch 117/200
#
# Epoch 00117: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0279 - mape: 5.0114 - val_loss: 8.8442e-04 - val_mae: 0.0213 - val_mape: 3.5901
# Epoch 118/200
#
# Epoch 00118: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0279 - mape: 5.0186 - val_loss: 8.7154e-04 - val_mae: 0.0212 - val_mape: 3.6115
# Epoch 119/200
#
# Epoch 00119: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0279 - mape: 5.0165 - val_loss: 8.8437e-04 - val_mae: 0.0213 - val_mape: 3.5900
# Epoch 120/200
#
# Epoch 00120: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0283 - mape: 5.0804 - val_loss: 9.1449e-04 - val_mae: 0.0220 - val_mape: 3.7814
# Epoch 121/200
#
# Epoch 00121: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0280 - mape: 5.0540 - val_loss: 9.2079e-04 - val_mae: 0.0218 - val_mape: 3.6576
# Epoch 122/200
#
# Epoch 00122: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0279 - mape: 5.0083 - val_loss: 8.9213e-04 - val_mae: 0.0216 - val_mape: 3.7019
# Epoch 123/200
#
# Epoch 00123: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0279 - mape: 5.0377 - val_loss: 8.7706e-04 - val_mae: 0.0212 - val_mape: 3.5805
# Epoch 124/200
#
# Epoch 00124: val_loss improved from 0.00087 to 0.00087, saving model to Bi-LSTM.hdf5
# 6/6 - 6s - loss: 0.0016 - mae: 0.0278 - mape: 4.9970 - val_loss: 8.6918e-04 - val_mae: 0.0211 - val_mape: 3.5840
# Epoch 125/200
#
# Epoch 00125: val_loss improved from 0.00087 to 0.00087, saving model to Bi-LSTM.hdf5
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9881 - val_loss: 8.6893e-04 - val_mae: 0.0211 - val_mape: 3.5861
# Epoch 126/200
#
# Epoch 00126: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0278 - mape: 4.9987 - val_loss: 8.6904e-04 - val_mae: 0.0211 - val_mape: 3.5916
# Epoch 127/200
#
# Epoch 00127: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0278 - mape: 5.0138 - val_loss: 8.8909e-04 - val_mae: 0.0213 - val_mape: 3.5971
# Epoch 128/200
#
# Epoch 00128: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0283 - mape: 5.0739 - val_loss: 8.7773e-04 - val_mae: 0.0213 - val_mape: 3.6431
# Epoch 129/200
#
# Epoch 00129: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0283 - mape: 5.1040 - val_loss: 8.7148e-04 - val_mae: 0.0211 - val_mape: 3.5789
# Epoch 130/200
#
# Epoch 00130: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0279 - mape: 5.0095 - val_loss: 8.7496e-04 - val_mae: 0.0211 - val_mape: 3.5787
# Epoch 131/200
#
# Epoch 00131: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0281 - mape: 5.0599 - val_loss: 8.7827e-04 - val_mae: 0.0213 - val_mape: 3.6452
# Epoch 132/200
#
# Epoch 00132: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0280 - mape: 5.0461 - val_loss: 8.7157e-04 - val_mae: 0.0211 - val_mape: 3.5789
# Epoch 133/200
#
# Epoch 00133: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9914 - val_loss: 8.7260e-04 - val_mae: 0.0212 - val_mape: 3.6183
# Epoch 134/200
#
# Epoch 00134: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0278 - mape: 5.0105 - val_loss: 8.8579e-04 - val_mae: 0.0213 - val_mape: 3.5920
# Epoch 135/200
#
# Epoch 00135: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9864 - val_loss: 8.8229e-04 - val_mae: 0.0214 - val_mape: 3.6625
# Epoch 136/200
#
# Epoch 00136: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0016 - mae: 0.0278 - mape: 5.0081 - val_loss: 8.8004e-04 - val_mae: 0.0212 - val_mape: 3.5842
# Epoch 137/200
#
# Epoch 00137: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9902 - val_loss: 8.7117e-04 - val_mae: 0.0212 - val_mape: 3.6098
# Epoch 138/200
#
# Epoch 00138: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9902 - val_loss: 8.6896e-04 - val_mae: 0.0211 - val_mape: 3.5888
# Epoch 139/200
#
# Epoch 00139: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9884 - val_loss: 8.7240e-04 - val_mae: 0.0211 - val_mape: 3.5786
# Epoch 140/200
#
# Epoch 00140: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9810 - val_loss: 8.7059e-04 - val_mae: 0.0211 - val_mape: 3.5797
# Epoch 141/200
#
# Epoch 00141: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9797 - val_loss: 8.7037e-04 - val_mae: 0.0211 - val_mape: 3.5798
# Epoch 142/200
#
# Epoch 00142: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9932 - val_loss: 8.6964e-04 - val_mae: 0.0211 - val_mape: 3.5815
# Epoch 143/200
#
# Epoch 00143: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.
# Epoch 200/200
#
# Epoch 00200: val_loss did not improve from 0.00087
# 6/6 - 6s - loss: 0.0015 - mae: 0.0277 - mape: 4.9826 - val_loss: 8.6981e-04 - val_mae: 0.0211 - val_mape: 3.6015
#
# Evaluation metrics
# Training Data - Loss: 0.0015, MAE: 0.0277, MAPE: 4.9860
# Validation Data - Loss: 0.0009, MAE: 0.0211, MAPE: 3.5852
# Test Data - Loss: 0.0014, MAE: 0.0245, MAPE: 4.2653

# %% [markdown]
# ### CNN + Bi-LSTM model

# %%
def create_model():
  in_seq = Input(shape=(seq_len, 5))

  x = Inception_A(in_seq, 32)
  x = Inception_A(x, 32)
  x = Inception_B(x, 32)
  x = Inception_B(x, 32)
  x = Inception_C(x, 32)
  x = Inception_C(x, 32)    
          
  x = Bidirectional(LSTM(128, return_sequences=True))(x)
  x = Bidirectional(LSTM(128, return_sequences=True))(x)
  x = Bidirectional(LSTM(64, return_sequences=True))(x) 
          
  avg_pool = GlobalAveragePooling1D()(x)
  max_pool = GlobalMaxPooling1D()(x)
  conc = concatenate([avg_pool, max_pool])
  conc = Dense(64, activation="relu")(conc)
  out = Dense(1, activation="sigmoid")(conc)      

  model = Model(inputs=in_seq, outputs=out)
  model.compile(loss="mse", optimizer="adam", metrics=['mae', 'mape'])     
  return model

model = create_model()

#model.summary()
#callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=2)
callback = tf.keras.callbacks.ModelCheckpoint('CNN+Bi-LSTM.hdf5', monitor='val_loss', save_best_only=True, verbose=1)

model.fit(X_train, y_train,
              batch_size=2048,
              verbose=2,
              callbacks=[callback],
              epochs=200,
              #shuffle=True,
              validation_data=(X_val, y_val),)    

model = tf.keras.models.load_model('/content/CNN+Bi-LSTM.hdf5')

###############################################################################
'''Calculate predictions and metrics'''

#Calculate predication for training, validation and test data
train_pred = model.predict(X_train)
val_pred = model.predict(X_val)
test_pred = model.predict(X_test)

#Print evaluation metrics for all datasets
train_eval = model.evaluate(X_train, y_train, verbose=0)
val_eval = model.evaluate(X_val, y_val, verbose=0)
test_eval = model.evaluate(X_test, y_test, verbose=0)
print(' ')
print('Evaluation metrics')
print('Training Data - Loss: {:.4f}, MAE: {:.4f}, MAPE: {:.4f}'.format(train_eval[0], train_eval[1], train_eval[2]))
print('Validation Data - Loss: {:.4f}, MAE: {:.4f}, MAPE: {:.4f}'.format(val_eval[0], val_eval[1], val_eval[2]))
print('Test Data - Loss: {:.4f}, MAE: {:.4f}, MAPE: {:.4f}'.format(test_eval[0], test_eval[1], test_eval[2]))

###############################################################################
'''Display results'''

fig = plt.figure(figsize=(15,15))
st = fig.suptitle("CNN + Bi-LSTM Model", fontsize=22)
st.set_y(1.02)

#Plot training data results
ax11 = fig.add_subplot(311)
ax11.plot(train_data[:, 3], label='IBM Closing Returns')
ax11.plot(train_pred, color='yellow', linewidth=3, label='Predicted IBM Closing Returns')
ax11.set_title("Training Data", fontsize=18)
ax11.set_xlabel('Date')
ax11.set_ylabel('IBM Closing Returns')

#Plot validation data results
ax21 = fig.add_subplot(312)
ax21.plot(val_data[:, 3], label='IBM Closing Returns')
ax21.plot(val_pred, color='yellow', linewidth=3, label='Predicted IBM Closing Returns')
ax21.set_title("Validation Data", fontsize=18)
ax21.set_xlabel('Date')
ax21.set_ylabel('IBM Closing Returns')

#Plot test data results
ax31 = fig.add_subplot(313)
ax31.plot(test_data[:, 3], label='IBM Closing Returns')
ax31.plot(test_pred, color='yellow', linewidth=3, label='Predicted IBM Closing Returns')
ax31.set_title("Test Data", fontsize=18)
ax31.set_xlabel('Date')
ax31.set_ylabel('IBM Closing Returns')
 
plt.tight_layout()
plt.legend(loc='best')
# Out:
# Epoch 1/200
#
# Epoch 00001: val_loss improved from inf to 0.00590, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 5s - loss: 0.0054 - mae: 0.0539 - mape: 9.3209 - val_loss: 0.0059 - val_mae: 0.0719 - val_mape: 11.9411
# Epoch 2/200
#
# Epoch 00002: val_loss improved from 0.00590 to 0.00396, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0018 - mae: 0.0315 - mape: 5.6412 - val_loss: 0.0040 - val_mae: 0.0573 - val_mape: 9.4896
# Epoch 3/200
#
# Epoch 00003: val_loss improved from 0.00396 to 0.00282, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0017 - mae: 0.0296 - mape: 5.3167 - val_loss: 0.0028 - val_mae: 0.0467 - val_mape: 7.7159
# Epoch 4/200
#
# Epoch 00004: val_loss improved from 0.00282 to 0.00249, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0016 - mae: 0.0284 - mape: 5.1324 - val_loss: 0.0025 - val_mae: 0.0432 - val_mape: 7.1387
# Epoch 5/200
#
# Epoch 00005: val_loss improved from 0.00249 to 0.00194, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0016 - mae: 0.0280 - mape: 5.0601 - val_loss: 0.0019 - val_mae: 0.0367 - val_mape: 6.0622
# Epoch 6/200
#
# Epoch 00006: val_loss improved from 0.00194 to 0.00155, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0015 - mae: 0.0277 - mape: 4.9819 - val_loss: 0.0016 - val_mae: 0.0315 - val_mape: 5.2082
# Epoch 7/200
#
# Epoch 00007: val_loss improved from 0.00155 to 0.00129, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0015 - mae: 0.0275 - mape: 4.9544 - val_loss: 0.0013 - val_mae: 0.0278 - val_mape: 4.5992
# Epoch 8/200
#
# Epoch 00008: val_loss improved from 0.00129 to 0.00112, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0015 - mae: 0.0274 - mape: 4.9334 - val_loss: 0.0011 - val_mae: 0.0250 - val_mape: 4.1601
# Epoch 9/200
#
# Epoch 00009: val_loss did not improve from 0.00112
# 6/6 - 1s - loss: 0.0015 - mae: 0.0275 - mape: 4.9536 - val_loss: 0.0012 - val_mae: 0.0263 - val_mape: 4.3700
# Epoch 10/200
#
# Epoch 00010: val_loss improved from 0.00112 to 0.00109, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0015 - mae: 0.0273 - mape: 4.9272 - val_loss: 0.0011 - val_mae: 0.0246 - val_mape: 4.0915
# Epoch 11/200
#
# Epoch 00011: val_loss did not improve from 0.00109
# 6/6 - 1s - loss: 0.0015 - mae: 0.0273 - mape: 4.9150 - val_loss: 0.0012 - val_mae: 0.0263 - val_mape: 4.3630
# Epoch 12/200
#
# Epoch 00012: val_loss did not improve from 0.00109
# 6/6 - 1s - loss: 0.0015 - mae: 0.0271 - mape: 4.8903 - val_loss: 0.0012 - val_mae: 0.0262 - val_mape: 4.3492
# Epoch 13/200
#
# Epoch 00013: val_loss did not improve from 0.00109
# 6/6 - 1s - loss: 0.0015 - mae: 0.0270 - mape: 4.8642 - val_loss: 0.0011 - val_mae: 0.0253 - val_mape: 4.1968
# Epoch 14/200
#
# Epoch 00014: val_loss did not improve from 0.00109
# 6/6 - 1s - loss: 0.
# Epoch 34/200
#
# Epoch 00034: val_loss did not improve from 0.00109
# 6/6 - 1s - loss: 3.6818e-04 - mae: 0.0143 - mape: 2.6169 - val_loss: 0.0020 - val_mae: 0.0378 - val_mape: 6.2373
# Epoch 35/200
#
# Epoch 00035: val_loss did not improve from 0.00109
# 6/6 - 1s - loss: 3.1483e-04 - mae: 0.0133 - mape: 2.4381 - val_loss: 0.0025 - val_mae: 0.0432 - val_mape: 7.1483
# Epoch 36/200
#
# Epoch 00036: val_loss did not improve from 0.00109
# 6/6 - 1s - loss: 2.8753e-04 - mae: 0.0127 - mape: 2.3224 - val_loss: 0.0018 - val_mae: 0.0355 - val_mape: 5.8622
# Epoch 37/200
#
# Epoch 00037: val_loss did not improve from 0.00109
# 6/6 - 1s - loss: 2.5314e-04 - mae: 0.0119 - mape: 2.1743 - val_loss: 0.0023 - val_mae: 0.0414 - val_mape: 6.8406
# Epoch 38/200
#
# Epoch 00038: val_loss did not improve from 0.00109
# 6/6 - 1s - loss: 2.2764e-04 - mae: 0.0114 - mape: 2.0748 - val_loss: 0.0022 - val_mae: 0.0402 - val_mape: 6.6421
# Epoch 39/200
#
# Epoch 00039: val_loss did not improve from 0.00109
# 6/6 - 1s - loss: 1.9614e-04 - mae: 0.0106 - mape: 1.9268 - val_loss: 0.0023 - val_mae: 0.0409 - val_mape: 6.7592
# Epoch 40/200
#
# Epoch 00040: val_loss did not improve from 0.00109
# 6/6 - 1s - loss: 1.8106e-04 - mae: 0.0102 - mape: 1.8637 - val_loss: 0.0018 - val_mae: 0.0349 - val_mape: 5.7632
# Epoch 41/200
#
# Epoch 00041: val_loss did not improve from 0.00109
# 6/6 - 1s - loss: 1.5822e-04 - mae: 0.0095 - mape: 1.7379 - val_loss: 0.0025 - val_mae: 0.0434 - val_mape: 7.1695
# Epoch 42/200
#
# Epoch 00042: val_loss did not improve from 0.00109
# 6/6 - 1s - loss: 1.4499e-04 - mae: 0.0091 - mape: 1.6651 - val_loss: 0.0017 - val_mae: 0.0335 - val_mape: 5.5305
# Epoch 43/200
#
# Epoch 00043: val_loss did not improve from 0.00109
# 6/6 - 1s - loss: 1.3208e-04 - mae: 0.0086 - mape: 1.5755 - val_loss: 0.0018 - val_mae: 0.0343 - val_mape: 5.6671
# Epoch 44/200
#
# Epoch 00044: val_loss did not improve from 0.00109
# 6/6 - 1s - loss: 1.3547e-04 - mae: 0.0089 - mape: 1.6166 - val_loss: 0.0017 - val_mae: 0.0333 - val_mape: 5.5080
# Epoch 45/200
#
# Epoch 00045: val_loss did not improve from 0.00109
# 6/6 - 1s - loss: 1.3683e-04 - mae: 0.0090 - mape: 1.6317 - val_loss: 0.0018 - val_mae: 0.0343 - val_mape: 5.6636
# Epoch 46/200
#
# Epoch 00046: val_loss did not improve from 0.00109
# 6/6 - 1s - loss: 1.3865e-04 - mae: 0.0091 - mape: 1.6479 - val_loss: 0.0015 - val_mae: 0.0306 - val_mape: 5.0682
# Epoch 47/200
#
# Epoch 00047: val_loss did not improve from 0.00109
# 6/6 - 1s - loss: 1.3248e-04 - mae: 0.0090 - mape: 1.6189 - val_loss: 0.0021 - val_mae: 0.0386 - val_mape: 6.3760
# Epoch 48/200
#
# Epoch 00048: val_loss did not improve from 0.00109
# 6/6 - 1s - loss: 1.0354e-04 - mae: 0.0078 - mape: 1.4148 - val_loss: 0.0014 - val_mae: 0.0287 - val_mape: 4.7581
# Epoch 49/200
#
# Epoch 00049: val_loss did not improve from 0.00109
# 6/6 - 1s - loss: 8.1067e-05 - mae: 0.0067 - mape: 1.2192 - val_loss: 0.0013 - val_mae: 0.0277 - val_mape: 4.5866
# Epoch 50/200
#
# Epoch 00050: val_loss improved from 0.00109 to 0.00104, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 2s - loss: 8.7903e-05 - mae: 0.0072 - mape: 1.3007 - val_loss: 0.0010 - val_mae: 0.0237 - val_mape: 3.9632
# Epoch 51/200
#
# Epoch 00051: val_loss improved from 0.00104 to 0.00103, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 2s - loss: 8.6403e-05 - mae: 0.0071 - mape: 1.2823 - val_loss: 0.0010 - val_mae: 0.0234 - val_mape: 3.9122
# Epoch 52/200
#
# Epoch 00052: val_loss did not improve from 0.00103
# 6/6 - 1s - loss: 8.0685e-05 - mae: 0.0069 - mape: 1.2448 - val_loss: 0.0011 - val_mae: 0.0242 - val_mape: 4.0431
# Epoch 53/200
#
# Epoch 00053: val_loss improved from 0.00103 to 0.00100, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 2s - loss: 6.6738e-05 - mae: 0.0061 - mape: 1.1156 - val_loss: 9.9513e-04 - val_mae: 0.0230 - val_mape: 3.8534
# Epoch 54/200
#
# Epoch 00054: val_loss improved from 0.00100 to 0.00099, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 2s - loss: 4.9899e-05 - mae: 0.0052 - mape: 0.9542 - val_loss: 9.9492e-04 - val_mae: 0.0229 - val_mape: 3.8561
# Epoch 55/200
#
# Epoch 00055: val_loss improved from 0.00099 to 0.00099, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 2s - loss: 4.8598e-05 - mae: 0.0052 - mape: 0.9577 - val_loss: 9.9207e-04 - val_mae: 0.0229 - val_mape: 3.8454
# Epoch 56/200
#
# Epoch 00056: val_loss did not improve from 0.00099
# 6/6 - 1s - loss: 3.9903e-05 - mae: 0.0047 - mape: 0.8629 - val_loss: 0.0010 - val_mae: 0.0230 - val_mape: 3.8733
# Epoch 57/200
#
# Epoch 00057: val_loss did not improve from 0.00099
# 6/6 - 1s - loss: 3.4620e-05 - mae: 0.0043 - mape: 0.8023 - val_loss: 0.0010 - val_mae: 0.0232 - val_mape: 3.9058
# Epoch 58/200
#
# Epoch 00058: val_loss did not improve from 0.00099
# 6/6 - 1s - loss: 4.0977e-05 - mae: 0.0048 - mape: 0.8838 - val_loss: 0.0011 - val_mae: 0.0241 - val_mape: 4.0382
# Epoch 59/200
#
# Epoch 00059: val_loss did not improve from 0.00099
# 6/6 - 1s - loss: 3.4571e-05 - mae: 0.0044 - mape: 0.8109 - val_loss: 0.0010 - val_mae: 0.0232 - val_mape: 3.9203
# Epoch 60/200
#
# Epoch 00060: val_loss did not improve from 0.00099
# 6/6 - 1s - loss: 2.7102e-05 - mae: 0.0038 - mape: 0.7133 - val_loss: 0.0010 - val_mae: 0.0231 - val_mape: 3.8975
# Epoch 61/200
#
# Epoch 00061: val_loss did not improve from 0.00099
# 6/6 - 1s - loss: 3.0873e-05 - mae: 0.0042 - mape: 0.7673 - val_loss: 0.0010 - val_mae: 0.0233 - val_mape: 3.9392
# Epoch 62/200
#
# Epoch 00062: val_loss did not improve from 0.00099
# 6/6 - 1s - loss: 2.8818e-05 - mae: 0.0040 - mape: 0.7365 - val_loss: 0.0010 - val_mae: 0.0233 - val_mape: 3.9374
# Epoch 63/200
#
# Epoch 00063: val_loss did not improve from 0.00099
# 6/6 - 1s - loss: 2.8869e-05 - mae: 0.0040 - mape: 0.7414 - val_loss: 0.0010 - val_mae: 0.0234 - val_mape: 3.9582
# Epoch 64/200
#
# Epoch 00064: val_loss did not improve from 0.00099
# 6/6 - 1s - loss: 4.7507e-05 - mae: 0.0055 - mape: 0.9802 - val_loss: 0.0010 - val_mae: 0.0237 - val_mape: 4.0372
# Epoch 65/200
#
# Epoch 00065: val_loss did not improve from 0.00099
# 6/6 - 1s - loss: 6.8676e-05 - mae: 0.0067 - mape: 1.1851 - val_loss: 0.0010 - val_mae: 0.0237 - val_mape: 4.0370
# Epoch 66/200
#
# Epoch 00066: val_loss did not improve from 0.00099
# 6/6 - 1s - loss: 1.0007e-04 - mae: 0.0082 - mape: 1.4450 - val_loss: 0.0011 - val_mae: 0.0241 - val_mape: 4.1172
# Epoch 67/200
#
# Epoch 00067: val_loss did not improve from 0.00099
# 6/6 - 1s - loss: 9.6839e-05 - mae: 0.0079 - mape: 1.3941 - val_loss: 0.0011 - val_mae: 0.0247 - val_mape: 4.2269
# Epoch 68/200
#
# Epoch 00068: val_loss did not improve from 0.00099
# 6/6 - 1s - loss: 8.9943e-05 - mae: 0.0075 - mape: 1.3217 - val_loss: 0.0011 - val_mae: 0.0244 - val_mape: 4.1733
# Epoch 69/200
#
# Epoch 00069: val_loss did not improve from 0.00099
# 6/6 - 1s - loss: 6.5682e-05 - mae: 0.0063 - mape: 1.1159 - val_loss: 0.0011 - val_mae: 0.0242 - val_mape: 4.0769
# Epoch 70/200
#
# Epoch 00070: val_loss did not improve from 0.00099
# 6/6 - 1s - loss:
- val_loss: 0.0012 - val_mae: 0.0265 - val_mape: 4.4901
# Epoch 190/200
#
# Epoch 00190: val_loss did not improve from 0.00099
# 6/6 - 1s - loss: 1.4833e-05 - mae: 0.0030 - mape: 0.5180 - val_loss: 0.0012 - val_mae: 0.0265 - val_mape: 4.4893
# Epoch 191/200
#
# Epoch 00191: val_loss did not improve from 0.00099
# 6/6 - 1s - loss: 1.3140e-05 - mae: 0.0028 - mape: 0.4864 - val_loss: 0.0013 - val_mae: 0.0274 - val_mape: 4.6408
# Epoch 192/200
#
# Epoch 00192: val_loss did not improve from 0.00099
# 6/6 - 1s - loss: 1.7202e-05 - mae: 0.0033 - mape: 0.5689 - val_loss: 0.0013 - val_mae: 0.0272 - val_mape: 4.6104
# Epoch 193/200
#
# Epoch 00193: val_loss did not improve from 0.00099
# 6/6 - 1s - loss: 1.7018e-05 - mae: 0.0032 - mape: 0.5556 - val_loss: 0.0013 - val_mae: 0.0273 - val_mape: 4.6292
# Epoch 194/200
#
# Epoch 00194: val_loss did not improve from 0.00099
# 6/6 - 1s - loss: 1.6097e-05 - mae: 0.0031 - mape: 0.5340 - val_loss: 0.0012 - val_mae: 0.0260 - val_mape: 4.4048
# Epoch 195/200
#
# Epoch 00195: val_loss did not improve from 0.00099
# 6/6 - 1s - loss: 1.5565e-05 - mae: 0.0031 - mape: 0.5352 - val_loss: 0.0013 - val_mae: 0.0270 - val_mape: 4.5686
# Epoch 196/200
#
# Epoch 00196: val_loss did not improve from 0.00099
# 6/6 - 1s - loss: 1.5076e-05 - mae: 0.0030 - mape: 0.5260 - val_loss: 0.0013 - val_mae: 0.0270 - val_mape: 4.5690
# Epoch 197/200
#
# Epoch 00197: val_loss did not improve from 0.00099
# 6/6 - 1s - loss: 1.7007e-05 - mae: 0.0033 - mape: 0.5653 - val_loss: 0.0012 - val_mae: 0.0263 - val_mape: 4.4747
# Epoch 198/200
#
# Epoch 00198: val_loss did not improve from 0.00099
# 6/6 - 1s - loss: 1.4901e-05 - mae: 0.0030 - mape: 0.5250 - val_loss: 0.0013 - val_mae: 0.0267 - val_mape: 4.5474
# Epoch 199/200
#
# Epoch 00199: val_loss did not improve from 0.00099
# 6/6 - 1s - loss: 1.6128e-05 - mae: 0.0032 - mape: 0.5477 - val_loss: 0.0012 - val_mae: 0.0266 - val_mape: 4.5163
# Epoch 200/200
#
# Epoch 00200: val_loss did not improve from 0.00099
# 6/6 - 1s - loss: 2.2984e-05 - mae: 0.0038 - mape: 0.6627 - val_loss: 0.0012 - val_mae: 0.0265 - val_mape: 4.5210
#
# Evaluation metrics
# Training Data - Loss: 0.0017, MAE: 0.0292, MAPE: 5.1843
# Validation Data - Loss: 0.0010, MAE: 0.0229, MAPE: 3.8454
# Test Data - Loss: 0.0015, MAE: 0.0264, MAPE: 4.5289

# %% [markdown]
# ## **Conculsion 1**
# When interpreting at the evaluation metrics it seems that the networks are predicting the next day closing price returns very well. The Bi-LSTM and CNN+Bi-LSTM networks have a **mean average percentage error** **(MAPE)** of  `3.58` and `3.84` for the validation set and `4.26` and `4.53` for the test set.
# Making it also obvious that the Bi-LSTM network is better than the CNN+Bi-LSTM network, which honestly surprised me.
#
# However, when taking a glance at the graphs of the validation and test set it becomes clear that the networks have merely found the center point of the return distributions. Over the entire course of the time series the networks do not divert greatly from the center.
#
# It seems that the right and left tail of the stock return distribution are not derivable from price data alone.
#
# I do have the following **hypotheses** that provide more room for investigation and might lead to better results.
#
# #### **Hypotheses**
#
# 1. The stock returns seem very rugged, which could make the networks interpret the distribution tails as semi-random. --> smooth returns with **moving average**
#
# 2. We do need more price data to derive temporal dependencies of the time series and get a better understanding of the distribution tails. --> Obtain **more price data** of different stocks, etfs, etc.
#
# 3. In order to predict the stock return distribution tails more accurately include additional features e.g. **financial news, company's balance sheet and P&L**
#
# The first hypothesis we'll also implement in this notebook.
#
# The second and third hypothesis will be addressed at a later stage.

# %% [markdown]
# # **Moving Average Analysis**

# %% [markdown]
# ## Loading IBM data again to apply a moving average effect

# %%
IBM_path = '/content/drive/My Drive/Capital_Market/Tutorials/Medium-Part1: The beginning of an autonomous trading bot/19620102_20200508_IBM_Prices.csv'

df = pd.read_csv(IBM_path, delimiter=',', usecols=['Date', 'Open', 'High', 'Low', 'Close', 'Volume'])

# Replace 0 to avoid dividing by 0 later on
df['Volume'].replace(to_replace=0, method='ffill', inplace=True) 
df.sort_values('Date', inplace=True)

# Apply moving average with a window of 10 days to all columns
df[['Open', 'High', 'Low', 'Close', 'Volume']] = df[['Open', 'High', 'Low', 'Close', 'Volume']].rolling(10).mean() 

# Drop all rows with NaN values
df.dropna(how='any', axis=0, inplace=True) 

df.head()
# Out:
#           Date      Open      High       Low     Close    Volume
# 9   1962-01-15  7.540000  7.578333  7.488667  7.515000  363040.0
# 10  1962-01-16  7.523333  7.561667  7.473333  7.499667  349440.0
# 11  1962-01-17  7.504667  7.536333  7.444000  7.465667  362560.0
# 12  1962-01-18  7.472667  7.511667  7.420000  7.441333  374080.0
# 13  1962-01-19  7.449333  7.490333  7.404000  7.432667  377760.0

# %% [markdown]
# ## Moving Average - Plot daily IBM closing prices

# %%
plt.figure(figsize=(15, 5))
plt.plot(df['Close'])
plt.xticks(range(0, df.shape[0], 1464), df['Date'].loc[::1464], rotation=0)
plt.ylabel('Price', fontsize=18)
plt.title("Close Price - Moving Average", fontsize=20)
plt.legend(['Close Price'], fontsize='x-large', loc='best')
plt.show()

# %% [markdown]
# ## Moving Average - Plot daily IBM volumes

# %%
plt.figure(figsize=(15, 5))
plt.plot(df['Volume'])
plt.xticks(range(0, df.shape[0], 1464), df['Date'].loc[::1464], rotation=0)
plt.ylabel('Volume', fontsize=18)
plt.title("Volume - Moving Average", fontsize=20)
plt.legend(['Volume'], fontsize='x-large', loc='best')
plt.show()

# %% [markdown]
# ## Moving Average - Calculate normalized percentage change for all columns

# %%
'''Calculate percentage change'''

df['Open'] = df['Open'].pct_change() # Create arithmetic returns column
df['High'] = df['High'].pct_change() # Create arithmetic returns column
df['Low'] = df['Low'].pct_change() # Create arithmetic returns column
df['Close'] = df['Close'].pct_change() # Create arithmetic returns column
df['Volume'] = df['Volume'].pct_change()

df.dropna(how='any', axis=0, inplace=True) # Drop all rows with NaN values

###############################################################################
'''Normalize price columns'''

min_return = min(df[['Open', 'High', 'Low', 'Close']].min(axis=0))
max_return = max(df[['Open', 'High', 'Low', 'Close']].max(axis=0))

# Min-max normalize price columns (0-1 range)
df['Open'] = (df['Open'] - min_return) / (max_return - min_return)
df['High'] = (df['High'] - min_return) / (max_return - min_return)
df['Low'] = (df['Low'] - min_return) / (max_return - min_return)
df['Close'] = (df['Close'] - min_return) / (max_return - min_return)

###############################################################################
'''Normalize volume column'''

min_volume = df['Volume'].min(axis=0)
max_volume = df['Volume'].max(axis=0)

# Min-max normalize volume columns (0-1 range)
df['Volume'] = (df['Volume'] - min_volume) / (max_volume - min_volume)

###############################################################################
'''Create training, validation and test split'''

times = sorted(df.index.values)
last_10pct = sorted(df.index.values)[-int(0.1*len(times))] # Last 10% of series
last_20pct = sorted(df.index.values)[-int(0.2*len(times))] # Last 20% of series

df_train = df[(df.index < last_20pct)]  # Training data are 80% of total data
df_val = df[(df.index >= last_20pct) & (df.index < last_10pct)]
df_test = df[(df.index >= last_10pct)]

# Remove date column
df_train.drop(columns=['Date'], inplace=True)
df_val.drop(columns=['Date'], inplace=True)
df_test.drop(columns=['Date'], inplace=True)

# Convert pandas columns into arrays
train_data = df_train.values
val_data = df_val.values
test_data = df_test.values
print('Training data shape: {}'.format(train_data.shape))
print('Validation data shape: {}'.format(val_data.shape))
print('Test data shape: {}'.format(test_data.shape))

df_train.head()
# Out:
# Training data shape: (11743, 5)
# Validation data shape: (1468, 5)
# Test data shape: (1467, 5)
#         Open      High       Low     Close    Volume
# 10  0.516547  0.516711  0.518941  0.519047  0.305158
# 11  0.512567  0.499793  0.491343  0.482399  0.363778
# 12  0.486361  0.500928  0.501647  0.501128  0.359267
# 13  0.503140  0.507292  0.517342  0.531919  0.342123
# 14  0.533253  0.547731  0.567569  0.556950  0.278825

# %% [markdown]
# ## Moving Average - Plot daily changes of close prices and volume

# %%
fig = plt.figure(figsize=(15,10))
st = fig.suptitle("Data Separation", fontsize=20)
st.set_y(0.92)

###############################################################################

ax1 = fig.add_subplot(211)
ax1.plot(np.arange(train_data.shape[0]), df_train['Close'], label='Training data')

ax1.plot(np.arange(train_data.shape[0], 
                   train_data.shape[0]+val_data.shape[0]), df_val['Close'], label='Validation data')

ax1.plot(np.arange(train_data.shape[0]+val_data.shape[0], 
                   train_data.shape[0]+val_data.shape[0]+test_data.shape[0]), df_test['Close'], label='Test data')
ax1.set_xlabel('Date')
ax1.set_ylabel('Normalized Closing Returns')

###############################################################################

ax2 = fig.add_subplot(212)
ax2.plot(np.arange(train_data.shape[0]), df_train['Volume'], label='Training data')

ax2.plot(np.arange(train_data.shape[0], 
                   train_data.shape[0]+val_data.shape[0]), df_val['Volume'], label='Validation data')

ax2.plot(np.arange(train_data.shape[0]+val_data.shape[0], 
                   train_data.shape[0]+val_data.shape[0]+test_data.shape[0]), df_test['Volume'], label='Test data')
ax2.set_xlabel('Date')
ax2.set_ylabel('Normalized Volume Changes')

plt.legend(loc='best')

# %% [markdown]
# ## Moving Average - Create chunks of training, validation and test data

# %%
# Training data
X_train, y_train = [], []
for i in range(seq_len, len(train_data)):
  X_train.append(train_data[i-seq_len:i]) # Chunks of training data with a length of 128 df-rows
  y_train.append(train_data[:, 3][i]) #Value of 4th column (Close Price) of df-row 128+1
X_train, y_train = np.array(X_train), np.array(y_train)

###############################################################################

# Validation data
X_val, y_val = [], []
for i in range(seq_len, len(val_data)):
    X_val.append(val_data[i-seq_len:i])
    y_val.append(val_data[:, 3][i])
X_val, y_val = np.array(X_val), np.array(y_val)

###############################################################################

# Test data
X_test, y_test = [], []
for i in range(seq_len, len(test_data)):
    X_test.append(test_data[i-seq_len:i])
    y_test.append(test_data[:, 3][i])    
X_test, y_test = np.array(X_test), np.array(y_test)

print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
# Out:
# (11615, 128, 5) (11615,)
# (1340, 128, 5) (1340,)

# %% [markdown]
# # **Moving Average - Testing different model architectures**

# %% [markdown]
# ### Moving Average - Bi-LSTM model

# %%
def create_model():
  in_seq = Input(shape = (seq_len, 5))
      
  x = Bidirectional(LSTM(128, return_sequences=True))(in_seq)
  x = Bidirectional(LSTM(128, return_sequences=True))(x)
  x = Bidirectional(LSTM(64, return_sequences=True))(x) 
          
  avg_pool = GlobalAveragePooling1D()(x)
  max_pool = GlobalMaxPooling1D()(x)
  conc = concatenate([avg_pool, max_pool])
  conc = Dense(64, activation="relu")(conc)
  out = Dense(1, activation="sigmoid")(conc)      

  model = Model(inputs=in_seq, outputs=out)
  model.compile(loss="mse", optimizer="adam", metrics=['mae', 'mape'])    
  return model

model = create_model()

#model.summary()
#callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=2)
callback = tf.keras.callbacks.ModelCheckpoint('Bi-LSTM.hdf5', monitor='val_loss', save_best_only=True, verbose=1)

model.fit(X_train, y_train,
              batch_size=2048,
              verbose=2,
              callbacks=[callback],
              epochs=200,
              #shuffle=True,
              validation_data=(X_val, y_val),)    

model = tf.keras.models.load_model('/content/Bi-LSTM.hdf5')

###############################################################################
'''Calculate predictions and metrics'''

#Calculate predication for training, validation and test data
train_pred = model.predict(X_train)
val_pred = model.predict(X_val)
test_pred = model.predict(X_test)

#Print evaluation metrics for all datasets
train_eval = model.evaluate(X_train, y_train, verbose=0)
val_eval = model.evaluate(X_val, y_val, verbose=0)
test_eval = model.evaluate(X_test, y_test, verbose=0)
print(' ')
print('Evaluation metrics')
print('Training Data - Loss: {:.4f}, MAE: {:.4f}, MAPE: {:.4f}'.format(train_eval[0], train_eval[1], train_eval[2]))
print('Validation Data - Loss: {:.4f}, MAE: {:.4f}, MAPE: {:.4f}'.format(val_eval[0], val_eval[1], val_eval[2]))
print('Test Data - Loss: {:.4f}, MAE: {:.4f}, MAPE: {:.4f}'.format(test_eval[0], test_eval[1], test_eval[2]))

###############################################################################
'''Display results'''

fig = plt.figure(figsize=(15,15))
st = fig.suptitle("Moving Average - Bi-LSTM Model", fontsize=22)
st.set_y(1.02)

#Plot training data results
ax11 = fig.add_subplot(311)
ax11.plot(train_data[:, 3], label='IBM Closing Returns')
ax11.plot(train_pred, label='Predicted IBM Closing Returns')
ax11.set_title("Training Data", fontsize=18)
ax11.set_xlabel('Date')
ax11.set_ylabel('IBM Closing Returns')

#Plot validation data results
ax21 = fig.add_subplot(312)
ax21.plot(val_data[:, 3], label='IBM Closing Returns')
ax21.plot(val_pred, label='Predicted IBM Closing Returns')
ax21.set_title("Validation Data", fontsize=18)
ax21.set_xlabel('Date')
ax21.set_ylabel('IBM Closing Returns')

#Plot test data results
ax31 = fig.add_subplot(313)
ax31.plot(test_data[:, 3], label='IBM Closing Returns')
ax31.plot(test_pred, label='Predicted IBM Closing Returns')
ax31.set_title("Test Data", fontsize=18)
ax31.set_xlabel('Date')
ax31.set_ylabel('IBM Closing Returns')
 
plt.tight_layout()
plt.legend(loc='best')
# Out:
# Epoch 1/200
#
# Epoch 00001: val_loss improved from inf to 0.00272, saving model to Bi-LSTM.hdf5
# 6/6 - 3s - loss: 0.0068 - mae: 0.0636 - mape: 12.2175 - val_loss: 0.0027 - val_mae: 0.0404 - val_mape: 7.4661
# Epoch 2/200
#
# Epoch 00002: val_loss improved from 0.00272 to 0.00264, saving model to Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0054 - mae: 0.0544 - mape: 10.6212 - val_loss: 0.0026 - val_mae: 0.0395 - val_mape: 7.2039
# Epoch 3/200
#
# Epoch 00003: val_loss did not improve from 0.00264
# 6/6 - 2s - loss: 0.0053 - mae: 0.0539 - mape: 10.5285 - val_loss: 0.0026 - val_mae: 0.0394 - val_mape: 7.1218
# Epoch 4/200
#
# Epoch 00004: val_loss improved from 0.00264 to 0.00262, saving model to Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0052 - mae: 0.0537 - mape: 10.4788 - val_loss: 0.0026 - val_mae: 0.0393 - val_mape: 7.1212
# Epoch 5/200
#
# Epoch 00005: val_loss did not improve from 0.00262
# 6/6 - 2s - loss: 0.0052 - mae: 0.0534 - mape: 10.4399 - val_loss: 0.0026 - val_mae: 0.0392 - val_mape: 7.0779
# Epoch 6/200
#
# Epoch 00006: val_loss did not improve from 0.00262
# 6/6 - 2s - loss: 0.0051 - mae: 0.0532 - mape: 10.4027 - val_loss: 0.0027 - val_mae: 0.0396 - val_mape: 7.0766
# Epoch 7/200
#
# Epoch 00007: val_loss improved from 0.00262 to 0.00261, saving model to Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0051 - mae: 0.0529 - mape: 10.3052 - val_loss: 0.0026 - val_mae: 0.0390 - val_mape: 6.9961
# Epoch 8/200
#
# Epoch 00008: val_loss improved from 0.00261 to 0.00250, saving model to Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0049 - mae: 0.0522 - mape: 10.2028 - val_loss: 0.0025 - val_mae: 0.0383 - val_mape: 6.9528
# Epoch 9/200
#
# Epoch 00009: val_loss improved from 0.00250 to 0.00245, saving model to Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0048 - mae: 0.0514 - mape: 10.0669 - val_loss: 0.0024 - val_mae: 0.0376 - val_mape: 6.7558
# Epoch 10/200
#
# Epoch 00010: val_loss did not improve from 0.00245
# 6/6 - 2s - loss: 0.0046 - mae: 0.0503 - mape: 9.7950 - val_loss: 0.0039 - val_mae: 0.0515 - val_mape: 9.7542
# Epoch 11/200
#
# Epoch 00011: val_loss did not improve from 0.00245
# 6/6 - 2s - loss: 0.0051 - mae: 0.0544 - mape: 10.6450 - val_loss: 0.0032 - val_mae: 0.0440 - val_mape: 7.6135
# Epoch 12/200
#
# Epoch 00012: val_loss did not improve from 0.00245
# 6/6 - 2s - loss: 0.0045 - mae: 0.0501 - mape: 9.7590 - val_loss: 0.0025 - val_mae: 0.0380 - val_mape: 6.6756
# Epoch 13/200
#
# Epoch 00013: val_loss improved from 0.00245 to 0.00219, saving model to Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0042 - mae: 0.0480 - mape: 9.3512 - val_loss: 0.0022 - val_mae: 0.0355 - val_mape: 6.2828
# Epoch 14/200
#
# Epoch 00014: val_loss improved from 0.00219 to 0.00190, saving model to Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0038 - mae: 0.0457 - mape: 8.8953 - val_loss: 0.0019 - val_mae: 0.0333 - val_mape: 6.0150
# Epoch 15/200
#
# Epoch 00015: val_loss did not improve from 0.00190
# 6/6 - 2s - loss: 0.0035 - mae: 0.0438 - mape: 8.5631 - val_loss: 0.0022 - val_mae: 0.0364 - val_mape: 6.3441
# Epoch 16/200
#
# Epoch 00016: val_loss did not improve from 0.00190
# 6/6 - 2s - loss: 0.0033 - mae: 0.0431 - mape: 8.3712 - val_loss: 0.0024 - val_mae: 0.0385 - val_mape: 6.6818
# Epoch 17/200
#
# Epoch 00017: val_loss improved from 0.00190 to 0.00153, saving model to Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0033 - mae: 0.0433 - mape: 8.3702 - val_loss: 0.0015 - val_mae: 0.0296 - val_mape: 5.2936
# Epoch 18/200
#
# Epoch 00018: val_loss did not improve from 0.00153
# 6/6 - 2s - loss: 0.0029 - mae: 0.0405 - mape: 7.8392 - val_loss: 0.0020 - val_mae: 0.0358 - val_mape: 6.6496
# Epoch 19/200
#
# Epoch 00019: val_loss improved from 0.00153 to 0.00133, saving model to Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0028 - mae: 0.0395 - mape: 7.6915 - val_loss: 0.0013 - val_mae: 0.0277 - val_mape: 5.0238
# Epoch 20/200
#
# Epoch 00020: val_loss improved from 0.00133 to 0.00128, saving model to Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0025 - mae: 0.0376 - mape: 7.2906 - val_loss: 0.0013 - val_mae: 0.0269 - val_mape: 4.8140
# Epoch 21/200
#
# Epoch 00021: val_loss improved from 0.00128 to 0.00122, saving model to Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0024 - mae: 0.0362 - mape: 7.0508 - val_loss: 0.0012 - val_mae: 0.0263 - val_mape: 4.6889
# Epoch 22/200
#
# Epoch 00022: val_loss improved from 0.00122 to 0.00109, saving model to Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0024 - mae: 0.0373 - mape: 7.2244 - val_loss: 0.0011 - val_mae: 0.0248 - val_mape: 4.4805
# Epoch 23/200
#
# Epoch 00023: val_loss did not improve from 0.00109
# 6/6 - 2s - loss: 0.0022 - mae: 0.0350 - mape: 6.8430 - val_loss: 0.0012 - val_mae: 0.0266 - val_mape: 4.7023
# Epoch 24/200
#
# Epoch 00024: val_loss improved from 0.00109 to 0.00101, saving model to Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0020 - mae: 0.0331 - mape: 6.4252 - val_loss: 0.0010 - val_mae: 0.0235 - val_mape: 4.2285
# Epoch 25/200
#
# Epoch 00025: val_loss did not improve from 0.00101
# 6/6 - 2s - loss: 0.0018 - mae: 0.0310 - mape: 6.0214 - val_loss: 0.0013 - val_mae: 0.0280 - val_mape: 5.1589
# Epoch 26/200
#
# Epoch 00026: val_loss did not improve from 0.00101
# 6/6 - 2s - loss: 0.0024 - mae: 0.0381 - mape: 7.3286 - val_loss: 0.0012 - val_mae: 0.0263 - val_mape: 4.6269
# Epoch 27/200
#
# Epoch 00027: val_loss did not improve from 0.00101
# 6/6 - 2s - loss: 0.0021 - mae: 0.0344 - mape: 6.6740 - val_loss: 0.0014 - val_mae: 0.0295 - val_mape: 5.4646
# Epoch 28/200
#
# Epoch 00028: val_loss did not improve from 0.00101
# 6/6 - 2s - loss: 0.0020 - mae: 0.0336 - mape: 6.4754 - val_loss: 0.0012 - val_mae: 0.0267 - val_mape: 4.9236
# Epoch 29/200
#
# Epoch 00029: val_loss improved from 0.00101 to 0.00088, saving model to Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0017 - mae: 0.0307 - mape: 5.9792 - val_loss: 8.8440e-04 - val_mae: 0.0222 - val_mape: 4.0142
# Epoch 30/200
#
# Epoch 00030: val_loss did not improve from 0.00088
# 6/6 - 2s - loss: 0.0017 - mae: 0.0310 - mape: 6.0148 - val_loss: 0.0010 - val_mae: 0.0240 - val_mape: 4.2380
# Epoch 31/200
#
# Epoch 00031: val_loss did not improve from 0.00088
# 6/6 - 2s - loss: 0.0018 - mae: 0.0313 - mape: 6.0816 - val_loss: 0.0011 - val_mae: 0.0258 - val_mape: 4.5367
# Epoch 32/200
#
# Epoch 00032: val_loss did not improve from 0.00088
# 6/6 - 2s - loss: 0.0017 - mae: 0.0306 - mape: 5.9165 - val_loss: 0.0016 - val_mae: 0.0328 - val_mape: 5.7528
# Epoch 33/200
#
# Epoch 00033: val_loss improved from 0.00088 to 0.00083, saving model to Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0019 - mae: 0.0325 - mape: 6.2539 - val_loss: 8.2810e-04 - val_mae: 0.0217 - val_mape: 3.9327
# Epoch 34/200
#
# Epoch 00034: val_loss did not improve from 0.00083
# 6/6 - 2s - loss: 0.0016 - mae: 0.0299 - mape: 5.7916 - val_loss: 9.3849e-04 - val_mae: 0.0233 - val_mape: 4.2685
# Epoch 35/200
#
# Epoch 00035: val_loss did not improve from 0.00083
# 6/6 - 2s - loss: 0.0016 - mae: 0.0289 - mape: 5.6142 - val_loss: 8.7270e-04 - val_mae: 0.0222 - val_mape: 4.0558
# Epoch 36/200
#
# Epoch 00036: val_loss did not improve from 0.00083
# 6/6 - 2s - loss: 0.0015 - mae: 0.0285 - mape: 5.5612 - val_loss: 8.3084e-04 - val_mae: 0.0215 - val_mape: 3.8512
# Epoch 37/200
#
# Epoch 00037: val_loss did not improve from 0.00083
# 6/6 - 2s - loss: 0.0015 - mae: 0.0282 - mape: 5.4834 - val_loss: 8.3440e-04 - val_mae: 0.0216 - val_mape: 3.8590
# Epoch 38/200
#
# Epoch 00038: val_loss did not improve from 0.00083
# 6/6 - 2s - loss: 0.0015 - mae: 0.0280 - mape: 5.4436 - val_loss: 8.3959e-04 - val_mae: 0.0217 - val_mape: 3.8695
# Epoch 39/200
#
# Epoch 00039: val_loss did not improve from 0.00083
# 6/6 - 2s - loss: 0.0015 - mae: 0.0280 - mape: 5.4499 - val_loss: 8.3614e-04 - val_mae: 0.0216 - val_mape: 3.8593
# Epoch 40/200
#
# Epoch 00040: val_loss improved from 0.00083 to 0.00082, saving model to Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0015 - mae: 0.0284 - mape: 5.5056 - val_loss: 8.2112e-04 - val_mae: 0.0216 - val_mape: 3.9273
# Epoch 41/200
#
# Epoch 00041: val_loss improved from 0.00082 to 0.00082, saving model to Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0015 - mae: 0.0281 - mape: 5.4629 - val_loss: 8.1654e-04 - val_mae: 0.0215 - val_mape: 3.9114
# Epoch 42/200
#
# Epoch 00042: val_loss did not improve from 0.00082
# 6/6 - 2s - loss: 0.0015 - mae: 0.0278 - mape: 5.4175 - val_loss: 8.3095e-04 - val_mae: 0.0217 - val_mape: 3.9647
# Epoch 43/200
#
# Epoch 00043: val_loss improved from 0.00082 to 0.00080, saving model to Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0014 - mae: 0.0275 - mape: 5.3636 - val_loss: 8.0445e-04 - val_mae: 0.0212 - val_mape: 3.7885
# Epoch 44/200
#
# Epoch 00044: val_loss did not improve from 0.00080
# 6/6 - 2s - loss: 0.0014 - mae: 0.0277 - mape: 5.3662 - val_loss: 8.2648e-04 - val_mae: 0.0218 - val_mape: 3.9783
# Epoch 45/200
#
# Epoch 00045: val_loss improved from 0.00080 to 0.00077, saving model to Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0015 - mae: 0.0281 - mape: 5.4496 - val_loss: 7.7076e-04 - val_mae: 0.0207 - val_mape: 3.7307
# Epoch 46/200
#
# Epoch 00046: val_loss did not improve from 0.00077
# 6/6 - 2s - loss: 0.0014 - mae: 0.0273 - mape: 5.3049 - val_loss: 7.7577e-04 - val_mae: 0.0208 - val_mape: 3.7323
# Epoch 47/200
#
# Epoch 00047: val_loss did not improve from 0.00077
# 6/6 - 2s - loss: 0.0014 - mae: 0.0273 - mape: 5.3048 - val_loss: 8.9455e-04 - val_mae: 0.0226 - val_mape: 4.0130
# Epoch 48/200
#
# Epoch 00048: val_loss improved from 0.00077 to 0.00077, saving model to Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0015 - mae: 0.0285 - mape: 5.5183 - val_loss: 7.6508e-04 - val_mae: 0.0207 - val_mape: 3.7124
# Epoch 49/200
#
# Epoch 00049: val_loss did not improve from 0.00077
# 6/6 - 2s - loss: 0.0014 - mae: 0.0271 - mape: 5.2704 - val_loss: 8.8276e-04 - val_mae: 0.0224 - val_mape: 3.9866
# Epoch 50/200
#
# Epoch 00050: val_loss did not improve from 0.00077
# 6/6 - 2s - loss: 0.0015 - mae: 0.0290 - mape: 5.6091 - val_loss: 9.1262e-04 - val_mae: 0.0235 - val_mape: 4.3351
# Epoch 51/200
#
# Epoch 00051: val_loss did not improve from 0.00077
# 6/6 - 2s - loss: 0.0015 - mae: 0.0287 - mape: 5.5777 - val_loss: 8.4098e-04 - val_mae: 0.0218 - val_mape: 3.8798
# Epoch 52/200
#
# Epoch 00052: val_loss improved from 0.00077 to 0.00076, saving model to Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0014 - mae: 0.0274 - mape: 5.3107 - val_loss: 7.5524e-04 - val_mae: 0.0206 - val_mape: 3.7229
# Epoch 53/200
#
# Epoch 00053: val_loss did not improve from 0.00076
# 6/6 - 2s - loss: 0.0014 - mae: 0.0276 - mape: 5.3526 - val_loss: 9.6877e-04 - val_mae: 0.0244 - val_mape: 4.4859
# Epoch 54/200
#
# Epoch 00054: val_loss did not improve from 0.00076
# 6/6 - 2s - loss: 0.0015 - mae: 0.0288 - mape: 5.5822 - val_loss: 7.6952e-04 - val_mae: 0.0207 - val_mape: 3.7069
# Epoch 55/200
#
# Epoch 00055: val_loss did not improve from 0.00076
# 6/6 - 2s - loss: 0.0014 - mae: 0.0269 - mape: 5.2311 - val_loss: 7.8199e-04 - val_mae: 0.0209 - val_mape: 3.7332
# Epoch 56/200
#
# Epoch 00056: val_loss improved from 0.00076 to 0.00075, saving model to Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0014 - mae: 0.0271 - mape: 5.2577 - val_loss: 7.4611e-04 - val_mae: 0.0204 - val_mape: 3.6974
# Epoch 57/200
#
# Epoch 00057: val_loss did not improve from 0.00075
# 6/6 - 2s - loss: 0.0014 - mae: 0.0268 - mape: 5.2150 - val_loss: 8.5177e-04 - val_mae: 0.0225 - val_mape: 4.1099
# Epoch 58/200
#
# Epoch 00058: val_loss improved from 0.00075 to 0.00074, saving model to Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0014 - mae: 0.0274 - mape: 5.3291 - val_loss: 7.4314e-04 - val_mae: 0.0205 - val_mape: 3.7148
# Epoch 59/200
#
# Epoch 00059: val_loss did not improve from 0.00074
# 6/6 - 2s - loss: 0.0014 - mae: 0.0277 - mape: 5.3605 - val_loss: 7.5457e-04 - val_mae: 0.0207 - val_mape: 3.7742
# Epoch 60/200
#
# Epoch 00060: val_loss improved from 0.00074 to 0.00074, saving model to Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0015 - mae: 0.0285 - mape: 5.5436 - val_loss: 7.3652e-04 - val_mae: 0.0203 - val_mape: 3.6649
# Epoch 61/200
#
# Epoch 00061: val_loss did not improve from 0.00074
# 6/6 - 2s - loss: 0.0013 - mae: 0.0267 - mape: 5.1846 - val_loss: 7.5813e-04 - val_mae: 0.0205 - val_mape: 3.6830
# Epoch 62/200
#
# Epoch 00062: val_loss did not improve from 0.00074
# 6/6 - 2s - loss: 0.0014 - mae: 0.0273 - mape: 5.2878 - val_loss: 7.4216e-04 - val_mae: 0.0205 - val_mape: 3.7328
# Epoch 63/200
#
# Epoch 00063: val_loss did not improve from 0.00074
# 6/6 - 2s - loss: 0.0015 - mae: 0.0287 - mape: 5.5575 - val_loss: 0.0010 - val_mae: 0.0245 - val_mape: 4.3134
# Epoch 64/200
#
# Epoch 00064: val_loss did not improve from 0.00074
# 6/6 - 2s - loss: 0.0014 - mae: 0.0277 - mape: 5.3708 - val_loss: 9.2460e-04 - val_mae: 0.0232 - val_mape: 4.1042
# Epoch 65/200
#
# Epoch 00065: val_loss improved from 0.00074 to 0.00073, saving model to Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0014 - mae: 0.0274 - mape: 5.3041 - val_loss: 7.3436e-04 - val_mae: 0.0203 - val_mape: 3.6879
# Epoch 66/200
#
# Epoch 00066: val_loss did not improve from 0.00073
# 6/6 - 2s - loss: 0.0013 - mae: 0.0263 - mape: 5.1296 - val_loss: 7.5703e-04 - val_mae: 0.0206 - val_mape: 3.6845
# Epoch 67/200
#
# Epoch 00067: val_loss did not improve from 0.00073
# 6/6 - 2s - loss: 0.0015 - mae: 0.0287 - mape: 5.5490 - val_loss: 8.5503e-04 - val_mae: 0.0221 - val_mape: 3.9185
# Epoch 68/200
#
# Epoch 00068: val_loss improved from 0.00073 to 0.00072, saving model to Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0014 - mae: 0.0281 - mape: 5.4444 - val_loss: 7.2337e-04 - val_mae: 0.0201 - val_mape: 3.6481
# Epoch 69/200
#
# Epoch 00069: val_loss did not improve from 0.00072
# 6/6 - 2s - loss: 0.0014 - mae: 0.0271 - mape: 5.2778 - val_loss: 7.2466e-04 - val_mae: 0.0202 - val_mape: 3.6445
# Epoch 70/200
#
# Epoch 00070: val_loss did not improve from 0.00072
# 6/6 - 2s - loss: 0.0013 - mae: 0.0266 - mape: 5.1644 - val_loss: 7.2343e-04 - val_mae: 0.0202 - val_mape: 3.6519
# Epoch 71/200
#
# Epoch 00071: val_loss did not improve from 0.00072
# 6/6 - 2s - loss: 0.0014 - mae: 0.0276 - mape: 5.3364 - val_loss: 9.7930e-04 - val_mae: 0.0247 - val_mape: 4.5692
# Epoch 72/200
#
# Epoch 00072: val_loss did not improve from 0.00072
# 6/6 - 2s - loss: 0.0014 - mae: 0.0281 - mape: 5.4633 - val_loss: 7.5669e-04 - val_mae: 0.0208 - val_mape: 3.8018
# Epoch 73/200
#
# Epoch 00073: val_loss did not improve from 0.00072
# 6/6 - 2s - loss: 0.0014 - mae: 0.0270 - mape: 5.2376 - val_loss: 7.8221e-04 - val_mae: 0.0210 - val_mape: 3.7402
# Epoch 74/200
#
# Epoch 00074: val_loss did not improve from 0.00072
# 6/6 - 2s - loss: 0.0013 - mae: 0.0267 - mape: 5.1713 - val_loss: 8.3190e-04 - val_mae: 0.0218 - val_mape: 3.8688
# Epoch 75/200
#
# Epoch 00075: val_loss did not improve from 0.00072
# 6/6 - 2s - loss: 0.0013 - mae: 0.0267 - mape: 5.1802 - val_loss: 8.4324e-04 - val_mae: 0.0220 - val_mape: 3.8971
# Epoch 76/200
#
# Epoch 00076: val_loss did not improve from 0.00072
# 6/6 - 2s - loss: 0.0014 - mae: 0.0271 - mape: 5.2713 - val_loss: 9.5141e-04 - val_mae: 0.0237 - val_mape: 4.1859
# Epoch 77/200
#
# Epoch 00077: val_loss did not improve from 0.00072
# 6/6 - 2s - loss: 0.0014 - mae: 0.0281 - mape: 5.4320 - val_loss: 8.3351e-04 - val_mae: 0.0218 - val_mape: 3.8626
# Epoch 78/200
#
# Epoch 00078: val_loss did not improve from 0.00072
# 6/6 - 2s - loss: 0.0015 - mae: 0.0289 - mape: 5.5999 - val_loss: 8.4963e-04 - val_mae: 0.0221 - val_mape: 3.9097
# Epoch 79/200
#
# Epoch 00079: val_loss did not improve from 0.00072
# 6/6 - 2s - loss: 0.0015 - mae: 0.0285 - mape: 5.5276 - val_loss: 8.2867e-04 - val_mae: 0.0217 - val_mape: 3.8538
# Epoch 80/200
#
# Epoch 00080: val_loss did not improve from 0.00072
# 6/6 - 2s - loss: 0.0014 - mae: 0.0272 - mape: 5.2657 - val_loss: 7.4625e-04 - val_mae: 0.0204 - val_mape: 3.6539
# Epoch 81/200
#
# Epoch 00081: val_loss did not improve from 0.00072
# 6/6 - 2s - loss: 0.0013 - mae: 0.0264 - mape: 5.1348 - val_loss: 8.0837e-04 - val_mae: 0.0214 - val_mape: 3.8093
# Epoch 82/200
#
# Epoch 00082: val_loss did not improve from 0.00072
# 6/6 - 2s - loss: 0.0013 - mae: 0.0267 - mape: 5.1737 - val_loss: 8.0319e-04 - val_mae: 0.0213 - val_mape: 3.7900
# Epoch 83/200
#
# Epoch 00083: val_loss improved from 0.00072 to 0.00072, saving model to Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0013 - mae: 0.0262 - mape: 5.0939 - val_loss: 7.1937e-04 - val_mae: 0.0200 - val_mape: 3.5901
# Epoch 84/200
#
# Epoch 00084: val_loss did not improve from 0.00072
# 6/6 - 2s - loss: 0.0013 - mae: 0.0261 - mape: 5.0696 - val_loss: 7.9082e-04 - val_mae: 0.0215 - val_mape: 3.9519
# Epoch 85/200
#
# Epoch 00085: val_loss improved from 0.00072 to 0.00070, saving model to Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0013 - mae: 0.0269 - mape: 5.2223 - val_loss: 6.9763e-04 - val_mae: 0.0197 - val_mape: 3.5689
# Epoch 86/200
#
# Epoch 00086: val_loss did not improve from 0.00070
# 6/6 - 2s - loss: 0.0013 - mae: 0.0263 - mape: 5.1157 - val_loss: 7.9867e-04 - val_mae: 0.0212 - val_mape: 3.7754
# Epoch 87/200
#
# Epoch 00087: val_loss did not improve from 0.00070
# 6/6 - 2s - loss: 0.0013 - mae: 0.0261 - mape: 5.0585 - val_loss: 7.3716e-04 - val_mae: 0.0203 - val_mape: 3.6267
# Epoch 88/200
#
# Epoch 00088: val_loss improved from 0.00070 to 0.00069, saving model to Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0012 - mae: 0.0255 - mape: 4.9524 - val_loss: 6.8938e-04 - val_mae: 0.0196 - val_mape: 3.5241
# Epoch 89/200
#
# Epoch 00089: val_loss did not improve from 0.00069
# 6/6 - 2s - loss: 0.0013 - mae: 0.0269 - mape: 5.2048 - val_loss: 8.1724e-04 - val_mae: 0.0221 - val_mape: 4.0611
# Epoch 90/200
#
# Epoch 00090: val_loss did not improve from 0.00069
# 6/6 - 2s - loss: 0.0014 - mae: 0.0279 - mape: 5.4130 - val_loss: 8.8092e-04 - val_mae: 0.0232 - val_mape: 4.2760
# Epoch 91/200
#
# Epoch 00091: val_loss did not improve from 0.00069
# 6/6 - 2s - loss: 0.0014 - mae: 0.0275 - mape: 5.3574 - val_loss: 7.0890e-04 - val_mae: 0.0201 - val_mape: 3.6504
# Epoch 92/200
#
# Epoch 00092: val_loss did not improve from 0.00069
# 6/6 - 2s - loss: 0.0012 - mae: 0.0258 - mape: 5.0100 - val_loss: 7.5074e-04 - val_mae: 0.0209 - val_mape: 3.8232
# Epoch 93/200
#
# Epoch 00093: val_loss did not improve from 0.00069
# 6/6 - 2s - loss: 0.0013 - mae: 0.0260 - mape: 5.0497 - val_loss: 7.9367e-04 - val_mae: 0.0216 - val_mape: 3.9611
# Epoch 94/200
#
# Epoch 00094: val_loss did not improve from 0.00069
# 6/6 - 2s - loss: 0.0013 - mae: 0.0260 - mape: 5.0624 - val_loss: 7.2735e-04 - val_mae: 0.0204 - val_mape: 3.7373
# Epoch 95/200
#
# Epoch 00095: val_loss improved from 0.00069 to 0.00068, saving model to Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0013 - mae: 0.0263 - mape: 5.0994 - val_loss: 6.7936e-04 - val_mae: 0.0194 - val_mape: 3.5016
# Epoch 96/200
#
# Epoch 00096: val_loss did not improve from 0.00068
# 6/6 - 2s - loss: 0.0012 - mae: 0.0253 - mape: 4.9230 - val_loss: 7.6393e-04 - val_mae: 0.0208 - val_mape: 3.7008
# Epoch 97/200
#
# Epoch 00097: val_loss did not improve from 0.00068
# 6/6 - 2s - loss: 0.0012 - mae: 0.0252 - mape: 4.8933 - val_loss: 7.4260e-04 - val_mae: 0.0204 - val_mape: 3.6468
# Epoch 98/200
#
# Epoch 00098: val_loss improved from 0.00068 to 0.00068, saving model to Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0012 - mae: 0.0259 - mape: 5.0289 - val_loss: 6.7672e-04 - val_mae: 0.0194 - val_mape: 3.4860
# Epoch 99/200
#
# Epoch 00099: val_loss improved from 0.00068 to 0.00067, saving model to Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0012 - mae: 0.0258 - mape: 5.0145 - val_loss: 6.6584e-04 - val_mae: 0.0193 - val_mape: 3.5099
# Epoch 100/200
#
# Epoch 00100: val_loss did not improve from 0.00067
# 6/6 - 2s - loss: 0.0012 - mae: 0.0251 - mape: 4.8916 - val_loss: 7.6006e-04 - val_mae: 0.0211 - val_mape: 3.8686
# Epoch 101/200
#
# Epoch 00101: val_loss improved from 0.00067 to 0.00066, saving model to Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0013 - mae: 0.0263 - mape: 5.1021 - val_loss: 6.6360e-04 - val_mae: 0.0192 - val_mape: 3.4829
# Epoch 102/200
#
# Epoch 00102: val_loss did not improve from 0.00066
# 6/6 - 2s - loss: 0.0013 - mae: 0.0271 - mape: 5.2461 - val_loss: 7.0044e-04 - val_mae: 0.0198 - val_mape: 3.5406
# Epoch 103/200
#
# Epoch 00103: val_loss did not improve from 0.00066
# 6/6 - 2s - loss: 0.0013 - mae: 0.0263 - mape: 5.1026 - val_loss: 9.1973e-04 - val_mae: 0.0235 - val_mape: 4.1599
# Epoch 104/200
#
# Epoch 00104: val_loss did not improve from 0.00066
# 6/6 - 2s - loss: 0.0012 - mae: 0.0257 - mape: 4.9733 - val_loss: 6.8108e-04 - val_mae: 0.0195 - val_mape: 3.4950
# Epoch 105/200
#
# Epoch 00105: val_loss did not improve from 0.00066
# 6/6 - 2s - loss: 0.0011 - mae: 0.0244 - mape: 4.7517 - val_loss: 6.8022e-04 - val_mae: 0.0195 - val_mape: 3.5011
# Epoch 106/200
#
# Epoch 00106: val_loss did not improve from 0.00066
# 6/6 - 2s - loss: 0.0013 - mae: 0.0263 - mape: 5.0841 - val_loss: 8.1042e-04 - val_mae: 0.0222 - val_mape: 4.1007
# Epoch 107/200
#
# Epoch 00107: val_loss did not improve from 0.00066
# 6/6 - 2s - loss: 0.0012 - mae: 0.0258 - mape: 5.0114 - val_loss: 0.0010 - val_mae: 0.0260 - val_mape: 4.7777
# Epoch 108/200
#
# Epoch 00108: val_loss did not improve from 0.00066
# 6/6 - 2s - loss: 0.0013 - mae: 0.0273 - mape: 5.2817 - val_loss: 7.6323e-04 - val_mae: 0.0214 - val_mape: 3.9518
# Epoch 109/200
#
# Epoch 00109: val_loss did not improve from 0.00066
# 6/6 - 2s - loss: 0.0013 - mae: 0.0264 - mape: 5.1335 - val_loss: 6.9141e-04 - val_mae: 0.0196 - val_mape: 3.5086
# Epoch 110/200
#
# Epoch 00110: val_loss improved from 0.00066 to 0.00063, saving model to Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.
val_loss did not improve from 0.00061
# 6/6 - 2s - loss: 0.0012 - mae: 0.0251 - mape: 4.8615 - val_loss: 7.0377e-04 - val_mae: 0.0201 - val_mape: 3.6819
# Epoch 132/200
#
# Epoch 00132: val_loss did not improve from 0.00061
# 6/6 - 2s - loss: 0.0012 - mae: 0.0259 - mape: 5.0058 - val_loss: 9.3141e-04 - val_mae: 0.0239 - val_mape: 4.3789
# Epoch 133/200
#
# Epoch 00133: val_loss did not improve from 0.00061
# 6/6 - 2s - loss: 0.0013 - mae: 0.0269 - mape: 5.2304 - val_loss: 8.2791e-04 - val_mae: 0.0215 - val_mape: 3.8374
# Epoch 134/200
#
# Epoch 00134: val_loss did not improve from 0.00061
# 6/6 - 2s - loss: 0.0013 - mae: 0.0260 - mape: 5.0382 - val_loss: 6.9935e-04 - val_mae: 0.0197 - val_mape: 3.5655
# Epoch 135/200
#
# Epoch 00135: val_loss did not improve from 0.00061
# 6/6 - 2s - loss: 0.0012 - mae: 0.0252 - mape: 4.9132 - val_loss: 6.7303e-04 - val_mae: 0.0193 - val_mape: 3.4872
# Epoch 136/200
#
# Epoch 00136: val_loss did not improve from 0.00061
# 6/6 - 2s - loss: 0.0012 - mae: 0.0247 - mape: 4.8070 - val_loss: 6.5871e-04 - val_mae: 0.0191 - val_mape: 3.4358
# Epoch 137/200
#
# Epoch 00137: val_loss did not improve from 0.00061
# 6/6 - 2s - loss: 0.0011 - mae: 0.0245 - mape: 4.7687 - val_loss: 6.3432e-04 - val_mae: 0.0187 - val_mape: 3.3683
# Epoch 138/200
#
# Epoch 00138: val_loss did not improve from 0.00061
# 6/6 - 2s - loss: 0.0011 - mae: 0.0238 - mape: 4.6496 - val_loss: 6.1463e-04 - val_mae: 0.0184 - val_mape: 3.3094
# Epoch 139/200
#
# Epoch 00139: val_loss did not improve from 0.00061
# 6/6 - 2s - loss: 0.0011 - mae: 0.0239 - mape: 4.6539 - val_loss: 6.6673e-04 - val_mae: 0.0198 - val_mape: 3.6066
# Epoch 140/200
#
# Epoch 00140: val_loss improved from 0.00061 to 0.00059, saving model to Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0011 - mae: 0.0237 - mape: 4.6263 - val_loss: 5.9320e-04 - val_mae: 0.0181 - val_mape: 3.2574
# Epoch 141/200
#
# Epoch 00141: val_loss did not improve from 0.00059
# 6/6 - 2s - loss: 0.0011 - mae: 0.0238 - mape: 4.6513 - val_loss: 6.7577e-04 - val_mae: 0.0196 - val_mape: 3.5034
# Epoch 142/200
#
# Epoch 00142: val_loss did not improve from 0.00059
# 6/6 - 2s - loss: 0.0011 - mae: 0.0239 - mape: 4.6633 - val_loss: 6.0717e-04 - val_mae: 0.0183 - val_mape: 3.2914
# Epoch 143/200
#
# Epoch 00143: val_loss improved from 0.00059 to 0.00057, saving model to Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0010 - mae: 0.0235 - mape: 4.5823 - val_loss: 5.7123e-04 - val_mae: 0.0177 - val_mape: 3.2225
# Epoch 144/200
#
# Epoch 00144: val_loss did not improve from 0.00057
# 6/6 - 2s - loss: 0.0010 - mae: 0.0231 - mape: 4.5113 - val_loss: 5.7354e-04 - val_mae: 0.0178 - val_mape: 3.2360
# Epoch 145/200
#
# Epoch 00145: val_loss did not improve from 0.00057
# 6/6 - 2s - loss: 9.9076e-04 - mae: 0.0228 - mape: 4.4478 - val_loss: 5.7464e-04 - val_mae: 0.0178 - val_mape: 3.2337
# Epoch 146/200
#
# Epoch 00146: val_loss did not improve from 0.00057
# 6/6 - 2s - loss: 9.9526e-04 - mae: 0.0229 - mape: 4.4586 - val_loss: 6.0020e-04 - val_mae: 0.0184 - val_mape: 3.3546
# Epoch 147/200
#
# Epoch 00147: val_loss did not improve from 0.00057
# 6/6 - 2s - loss: 9.9929e-04 - mae: 0.0230 - mape: 4.4781 - val_loss: 5.7909e-04 - val_mae: 0.0178 - val_mape: 3.2008
# Epoch 148/200
#
# Epoch 00148: val_loss improved from 0.00057 to 0.00056, saving model to Bi-LSTM.hdf5
# 6/6 - 2s - loss: 9.9350e-04 - mae: 0.0229 - mape: 4.4541 - val_loss: 5.6324e-04 - val_mae: 0.0175 - val_mape: 3.1584
# Epoch 149/200
#
# Epoch 00149: val_loss did not improve from 0.00056
# 6/6 - 2s - loss: 0.0011 - mae: 0.0241 - mape: 4.6812 - val_loss: 5.7552e-04 - val_mae: 0.0177 - val_mape: 3.1866
# Epoch 150/200
#
# Epoch 00150: val_loss did not improve from 0.00056
# 6/6 - 2s - loss: 9.7702e-04 - mae: 0.0226 - mape: 4.4057 - val_loss: 5.8959e-04 - val_mae: 0.0180 - val_mape: 3.2336
# Epoch 151/200
#
# Epoch 00151: val_loss did not improve from 0.00056
# 6/6 - 2s - loss: 0.0010 - mae: 0.0232 - mape: 4.5065 - val_loss: 6.0645e-04 - val_mae: 0.0186 - val_mape: 3.4069
# Epoch 152/200
#
# Epoch 00152: val_loss improved from 0.00056 to 0.00056, saving model to Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0011 - mae: 0.0241 - mape: 4.6718 - val_loss: 5.5726e-04 - val_mae: 0.0175 - val_mape: 3.1982
# Epoch 153/200
#
# Epoch 00153: val_loss did not improve from 0.00056
# 6/6 - 2s - loss: 0.0010 - mae: 0.0238 - mape: 4.6215 - val_loss: 6.5144e-04 - val_mae: 0.0192 - val_mape: 3.4323
# Epoch 154/200
#
# Epoch 00154: val_loss did not improve from 0.00056
# 6/6 - 2s - loss: 0.0010 - mae: 0.0236 - mape: 4.5729 - val_loss: 7.2231e-04 - val_mae: 0.0206 - val_mape: 3.6666
# Epoch 155/200
#
# Epoch 00155: val_loss did not improve from 0.00056
# 6/6 - 2s - loss: 0.0010 - mae: 0.0235 - mape: 4.5690 - val_loss: 5.7530e-04 - val_mae: 0.0177 - val_mape: 3.1890
# Epoch 156/200
#
# Epoch 00156: val_loss did not improve from 0.00056
# 6/6 - 2s - loss: 9.6602e-04 - mae: 0.0225 - mape: 4.3863 - val_loss: 5.7098e-04 - val_mae: 0.0177 - val_mape: 3.1851
# Epoch 157/200
#
# Epoch 00157: val_loss did not improve from 0.00056
# 6/6 - 2s - loss: 9.6836e-04 - mae: 0.0226 - mape: 4.3870 - val_loss: 5.5780e-04 - val_mae: 0.0175 - val_mape: 3.1926
# Epoch 158/200
#
# Epoch 00158: val_loss improved from 0.00056 to 0.00054, saving model to Bi-LSTM.hdf5
# 6/6 - 2s - loss: 9.5481e-04 - mae: 0.0224 - mape: 4.3582 - val_loss: 5.4323e-04 - val_mae: 0.0172 - val_mape: 3.1052
# Epoch 159/200
#
# Epoch 00159: val_loss did not improve from 0.00054
# 6/6 - 2s - loss: 9.4728e-04 - mae: 0.0223 - mape: 4.3401 - val_loss: 5.4485e-04 - val_mae: 0.0172 - val_mape: 3.1130
# Epoch 160/200
#
# Epoch 00160: val_loss did not improve from 0.00054
# 6/6 - 2s - loss: 9.6045e-04 - mae: 0.0225 - mape: 4.3664 - val_loss: 8.5557e-04 - val_mae: 0.0234 - val_mape: 4.2994
# Epoch 161/200
#
# Epoch 00161: val_loss did not improve from 0.00054
# 6/6 - 2s - loss: 0.0012 - mae: 0.0260 - mape: 5.0244 - val_loss: 5.5351e-04 - val_mae: 0.0173 - val_mape: 3.1345
# Epoch 162/200
#
# Epoch 00162: val_loss did not improve from 0.00054
# 6/6 - 2s - loss: 0.0011 - mae: 0.0237 - mape: 4.5933 - val_loss: 5.7783e-04 - val_mae: 0.0179 - val_mape: 3.2743
# Epoch 163/200
#
# Epoch 00163: val_loss did not improve from 0.00054
# 6/6 - 2s - loss: 0.0010 - mae: 0.0234 - mape: 4.5328 - val_loss: 5.7520e-04 - val_mae: 0.0179 - val_mape: 3.2623
# Epoch 164/200
#
# Epoch 00164: val_loss improved from 0.00054 to 0.00054, saving model to Bi-LSTM.hdf5
# 6/6 - 2s - loss: 9.7095e-04 - mae: 0.0226 - mape: 4.3975 - val_loss: 5.4241e-04 - val_mae: 0.0172 - val_mape: 3.1324
# Epoch 165/200
#
# Epoch 00165: val_loss did not improve from 0.00054
# 6/6 - 2s - loss: 9.6838e-04 - mae: 0.0226 - mape: 4.3985 - val_loss: 5.5153e-04 - val_mae: 0.0173 - val_mape: 3.1225
# Epoch 166/200
#
# Epoch 00166: val_loss improved from 0.00054 to 0.00054, saving model to Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0010 - mae: 0.0235 - mape: 4.5579 - val_loss: 5.4031e-04 - val_mae: 0.0172 - val_mape: 3.1317
# Epoch 167/200
#
# Epoch 00167: val_loss improved from 0.00054 to 0.00054, saving model to Bi-LSTM.hdf5
# 6/6 - 2s - loss: 9
# Epoch 188/200
#
# Epoch 00188: val_loss did not improve from 0.00053
# 6/6 - 2s - loss: 9.3256e-04 - mae: 0.0222 - mape: 4.2999 - val_loss: 5.3724e-04 - val_mae: 0.0171 - val_mape: 3.1165
# Epoch 189/200
#
# Epoch 00189: val_loss did not improve from 0.00053
# 6/6 - 2s - loss: 9.3208e-04 - mae: 0.0222 - mape: 4.3174 - val_loss: 5.3548e-04 - val_mae: 0.0170 - val_mape: 3.0760
# Epoch 190/200
#
# Epoch 00190: val_loss did not improve from 0.00053
# 6/6 - 2s - loss: 9.5622e-04 - mae: 0.0226 - mape: 4.3746 - val_loss: 5.3564e-04 - val_mae: 0.0170 - val_mape: 3.0764
# Epoch 191/200
#
# Epoch 00191: val_loss improved from 0.00053 to 0.00053, saving model to Bi-LSTM.hdf5
# 6/6 - 2s - loss: 9.2553e-04 - mae: 0.0221 - mape: 4.2843 - val_loss: 5.3216e-04 - val_mae: 0.0170 - val_mape: 3.0885
# Epoch 192/200
#
# Epoch 00192: val_loss did not improve from 0.00053
# 6/6 - 2s - loss: 9.2802e-04 - mae: 0.0221 - mape: 4.2978 - val_loss: 5.3483e-04 - val_mae: 0.0170 - val_mape: 3.0761
# Epoch 193/200
#
# Epoch 00193: val_loss did not improve from 0.00053
# 6/6 - 2s - loss: 9.2843e-04 - mae: 0.0221 - mape: 4.2990 - val_loss: 5.9358e-04 - val_mae: 0.0184 - val_mape: 3.3645
# Epoch 194/200
#
# Epoch 00194: val_loss did not improve from 0.00053
# 6/6 - 2s - loss: 9.8345e-04 - mae: 0.0230 - mape: 4.4609 - val_loss: 5.7483e-04 - val_mae: 0.0178 - val_mape: 3.1910
# Epoch 195/200
#
# Epoch 00195: val_loss did not improve from 0.00053
# 6/6 - 2s - loss: 9.6895e-04 - mae: 0.0227 - mape: 4.3994 - val_loss: 5.4404e-04 - val_mae: 0.0173 - val_mape: 3.1599
# Epoch 196/200
#
# Epoch 00196: val_loss did not improve from 0.00053
# 6/6 - 2s - loss: 9.9243e-04 - mae: 0.0232 - mape: 4.4903 - val_loss: 6.9346e-04 - val_mae: 0.0204 - val_mape: 3.7594
# Epoch 197/200
#
# Epoch 00197: val_loss did not improve from 0.00053
# 6/6 - 2s - loss: 0.0011 - mae: 0.0245 - mape: 4.7324 - val_loss: 7.0323e-04 - val_mae: 0.0207 - val_mape: 3.8095
# Epoch 198/200
#
# Epoch 00198: val_loss did not improve from 0.00053
# 6/6 - 2s - loss: 0.0010 - mae: 0.0236 - mape: 4.5838 - val_loss: 6.5294e-04 - val_mae: 0.0197 - val_mape: 3.6139
# Epoch 199/200
#
# Epoch 00199: val_loss did not improve from 0.00053
# 6/6 - 2s - loss: 9.8868e-04 - mae: 0.0231 - mape: 4.4843 - val_loss: 5.3635e-04 - val_mae: 0.0171 - val_mape: 3.1067
# Epoch 200/200
#
# Epoch 00200: val_loss did not improve from 0.00053
# 6/6 - 2s - loss: 9.4927e-04 - mae: 0.0224 - mape: 4.3574 - val_loss: 5.5057e-04 - val_mae: 0.0173 - val_mape: 3.1215
#
# Evaluation metrics
# Training Data - Loss: 0.0009, MAE: 0.0221, MAPE: 4.3068
# Validation Data - Loss: 0.0005, MAE: 0.0170, MAPE: 3.0885
# Test Data - Loss: 0.0009, MAE: 0.0201, MAPE: 4.0884

# %% [markdown]
# ### Moving Average - CNN + Bi-LSTM model

# %%
def create_model():
  in_seq = Input(shape=(seq_len, 5))

  x = Inception_A(in_seq, 32)
  x = Inception_A(x, 32)
  x = Inception_B(x, 32)
  x = Inception_B(x, 32)
  x = Inception_C(x, 32)
  x = Inception_C(x, 32)    
          
  x = Bidirectional(LSTM(128, return_sequences=True))(x)
  x = Bidirectional(LSTM(128, return_sequences=True))(x)
  x = Bidirectional(LSTM(64, return_sequences=True))(x) 
          
  avg_pool = GlobalAveragePooling1D()(x)
  max_pool = GlobalMaxPooling1D()(x)
  conc = concatenate([avg_pool, max_pool])
  conc = Dense(64, activation="relu")(conc)
  out = Dense(1, activation="sigmoid")(conc)      

  model = Model(inputs=in_seq, outputs=out)
  model.compile(loss="mse", optimizer="adam", metrics=['mae', 'mape'])     
  return model

model = create_model()

#model.summary()
#callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=2)
callback = tf.keras.callbacks.ModelCheckpoint('CNN+Bi-LSTM.hdf5', monitor='val_loss', save_best_only=True, verbose=1)

model.fit(X_train, y_train,
              batch_size=2048,
              verbose=2,
              callbacks=[callback],
              epochs=200,
              #shuffle=True,
              validation_data=(X_val, y_val),)    

model = tf.keras.models.load_model('/content/CNN+Bi-LSTM.hdf5')

###############################################################################
'''Calculate predictions and metrics'''

#Calculate predication for training, validation and test data
train_pred = model.predict(X_train)
val_pred = model.predict(X_val)
test_pred = model.predict(X_test)

#Print evaluation metrics for all datasets
train_eval = model.evaluate(X_train, y_train, verbose=0)
val_eval = model.evaluate(X_val, y_val, verbose=0)
test_eval = model.evaluate(X_test, y_test, verbose=0)
print(' ')
print('Evaluation metrics')
print('Training Data - Loss: {:.4f}, MAE: {:.4f}, MAPE: {:.4f}'.format(train_eval[0], train_eval[1], train_eval[2]))
print('Validation Data - Loss: {:.4f}, MAE: {:.4f}, MAPE: {:.4f}'.format(val_eval[0], val_eval[1], val_eval[2]))
print('Test Data - Loss: {:.4f}, MAE: {:.4f}, MAPE: {:.4f}'.format(test_eval[0], test_eval[1], test_eval[2]))

###############################################################################
'''Display results'''

fig = plt.figure(figsize=(15,15))
st = fig.suptitle("Moving Average - CNN + Bi-LSTM Model", fontsize=22)
st.set_y(1.02)

#Plot training data results
ax11 = fig.add_subplot(311)
ax11.plot(train_data[:, 3], label='IBM Closing Returns')
ax11.plot(train_pred, label='Predicted IBM Closing Returns')
ax11.set_title("Training Data", fontsize=18)
ax11.set_xlabel('Date')
ax11.set_ylabel('IBM Closing Returns')

#Plot validation data results
ax21 = fig.add_subplot(312)
ax21.plot(val_data[:, 3], label='IBM Closing Returns')
ax21.plot(val_pred, label='Predicted IBM Closing Returns')
ax21.set_title("Validation Data", fontsize=18)
ax21.set_xlabel('Date')
ax21.set_ylabel('IBM Closing Returns')

#Plot test data results
ax31 = fig.add_subplot(313)
ax31.plot(test_data[:, 3], label='IBM Closing Returns')
ax31.plot(test_pred, label='Predicted IBM Closing Returns')
ax31.set_title("Test Data", fontsize=18)
ax31.set_xlabel('Date')
ax31.set_ylabel('IBM Closing Returns')
 
plt.tight_layout()
plt.legend(loc='best')
# Out:
# Epoch 1/200
#
# Epoch 00001: val_loss improved from inf to 0.00441, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 4s - loss: 0.0105 - mae: 0.0783 - mape: 14.9777 - val_loss: 0.0044 - val_mae: 0.0533 - val_mape: 9.1907
# Epoch 2/200
#
# Epoch 00002: val_loss did not improve from 0.00441
# 6/6 - 1s - loss: 0.0055 - mae: 0.0556 - mape: 10.9848 - val_loss: 0.0045 - val_mae: 0.0539 - val_mape: 9.2859
# Epoch 3/200
#
# Epoch 00003: val_loss did not improve from 0.00441
# 6/6 - 1s - loss: 0.0051 - mae: 0.0530 - mape: 10.4110 - val_loss: 0.0045 - val_mae: 0.0537 - val_mape: 9.2582
# Epoch 4/200
#
# Epoch 00004: val_loss improved from 0.00441 to 0.00429, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0048 - mae: 0.0518 - mape: 10.1567 - val_loss: 0.0043 - val_mae: 0.0524 - val_mape: 9.0493
# Epoch 5/200
#
# Epoch 00005: val_loss did not improve from 0.00429
# 6/6 - 1s - loss: 0.0043 - mae: 0.0489 - mape: 9.5619 - val_loss: 0.0044 - val_mae: 0.0531 - val_mape: 9.1579
# Epoch 6/200
#
# Epoch 00006: val_loss did not improve from 0.00429
# 6/6 - 1s - loss: 0.0030 - mae: 0.0405 - mape: 7.9807 - val_loss: 0.0048 - val_mae: 0.0559 - val_mape: 9.6292
# Epoch 7/200
#
# Epoch 00007: val_loss improved from 0.00429 to 0.00349, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0019 - mae: 0.0328 - mape: 6.4064 - val_loss: 0.0035 - val_mae: 0.0461 - val_mape: 8.0294
# Epoch 8/200
#
# Epoch 00008: val_loss did not improve from 0.00349
# 6/6 - 1s - loss: 0.0016 - mae: 0.0293 - mape: 5.7674 - val_loss: 0.0037 - val_mae: 0.0478 - val_mape: 8.2966
# Epoch 9/200
#
# Epoch 00009: val_loss improved from 0.00349 to 0.00330, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0013 - mae: 0.0266 - mape: 5.1949 - val_loss: 0.0033 - val_mae: 0.0446 - val_mape: 7.7961
# Epoch 10/200
#
# Epoch 00010: val_loss improved from 0.00330 to 0.00318, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0011 - mae: 0.0245 - mape: 4.8114 - val_loss: 0.0032 - val_mae: 0.0437 - val_mape: 7.6529
# Epoch 11/200
#
# Epoch 00011: val_loss improved from 0.00318 to 0.00313, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 2s - loss: 0.0010 - mae: 0.0237 - mape: 4.6177 - val_loss: 0.0031 - val_mae: 0.0433 - val_mape: 7.5970
# Epoch 12/200
#
# Epoch 00012: val_loss improved from 0.00313 to 0.00305, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 2s - loss: 9.2814e-04 - mae: 0.0225 - mape: 4.3652 - val_loss: 0.0031 - val_mae: 0.0427 - val_mape: 7.5051
# Epoch 13/200
#
# Epoch 00013: val_loss did not improve from 0.00305
# 6/6 - 1s - loss: 8.5805e-04 - mae: 0.0218 - mape: 4.2286 - val_loss: 0.0032 - val_mae: 0.0438 - val_mape: 7.6679
# Epoch 14/200
#
# Epoch 00014: val_loss improved from 0.00305 to 0.00294, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 2s - loss: 8.1041e-04 - mae: 0.0212 - mape: 4.0860 - val_loss: 0.0029 - val_mae: 0.0418 - val_mape: 7.3693
# Epoch 15/200
#
# Epoch 00015: val_loss improved from 0.00294 to 0.00290, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 2s - loss: 7.6253e-04 - mae: 0.0206 - mape: 3.9780 - val_loss: 0.0029 - val_mae: 0.0415 - val_mape: 7.3164
# Epoch 16/200
#
# Epoch 00016: val_loss did not improve from 0.00290
# 6/6 - 1s - loss: 7.3756e-04 - mae: 0.0204 - mape: 3.9268 - val_loss: 0.0029 - val_mae: 0.0417 - val_mape: 7.3547
# Epoch 17/200
#
# Epoch 00017: val_loss did not improve from 0.00290
# 6/6 - 1s - loss: 7.0884e-04 - mae: 0.0200 - mape: 3.8569 - val_loss: 0.0032 - val_mae: 0.0436 - val_mape: 7.6189
# Epoch 18/200
#
# Epoch 00018: val_loss did not improve from
val_loss did not improve from 0.00287
# 6/6 - 1s - loss: 2.0669e-04 - mae: 0.0112 - mape: 2.1552 - val_loss: 0.0031 - val_mae: 0.0439 - val_mape: 7.6413
# Epoch 37/200
#
# Epoch 00037: val_loss did not improve from 0.00287
# 6/6 - 1s - loss: 1.8655e-04 - mae: 0.0106 - mape: 2.0332 - val_loss: 0.0031 - val_mae: 0.0435 - val_mape: 7.5726
# Epoch 38/200
#
# Epoch 00038: val_loss improved from 0.00287 to 0.00287, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 2s - loss: 1.5294e-04 - mae: 0.0096 - mape: 1.8454 - val_loss: 0.0029 - val_mae: 0.0418 - val_mape: 7.3031
# Epoch 39/200
#
# Epoch 00039: val_loss did not improve from 0.00287
# 6/6 - 1s - loss: 1.5893e-04 - mae: 0.0098 - mape: 1.8778 - val_loss: 0.0031 - val_mae: 0.0438 - val_mape: 7.6161
# Epoch 40/200
#
# Epoch 00040: val_loss did not improve from 0.00287
# 6/6 - 1s - loss: 1.4288e-04 - mae: 0.0092 - mape: 1.7608 - val_loss: 0.0029 - val_mae: 0.0424 - val_mape: 7.4005
# Epoch 41/200
#
# Epoch 00041: val_loss improved from 0.00287 to 0.00274, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 2s - loss: 1.7847e-04 - mae: 0.0106 - mape: 2.0340 - val_loss: 0.0027 - val_mae: 0.0407 - val_mape: 7.1394
# Epoch 42/200
#
# Epoch 00042: val_loss did not improve from 0.00274
# 6/6 - 1s - loss: 1.6316e-04 - mae: 0.0099 - mape: 1.9087 - val_loss: 0.0028 - val_mae: 0.0414 - val_mape: 7.2293
# Epoch 43/200
#
# Epoch 00043: val_loss did not improve from 0.00274
# 6/6 - 1s - loss: 1.5510e-04 - mae: 0.0098 - mape: 1.8665 - val_loss: 0.0030 - val_mae: 0.0428 - val_mape: 7.4402
# Epoch 44/200
#
# Epoch 00044: val_loss improved from 0.00274 to 0.00271, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 2s - loss: 1.4154e-04 - mae: 0.0093 - mape: 1.7691 - val_loss: 0.0027 - val_mae: 0.0405 - val_mape: 7.0906
# Epoch 45/200
#
# Epoch 00045: val_loss did not improve from 0.00271
# 6/6 - 1s - loss: 1.2164e-04 - mae: 0.0085 - mape: 1.6559 - val_loss: 0.0027 - val_mae: 0.0408 - val_mape: 7.1258
# Epoch 46/200
#
# Epoch 00046: val_loss improved from 0.00271 to 0.00259, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 2s - loss: 9.5210e-05 - mae: 0.0075 - mape: 1.4659 - val_loss: 0.0026 - val_mae: 0.0395 - val_mape: 6.9019
# Epoch 47/200
#
# Epoch 00047: val_loss did not improve from 0.00259
# 6/6 - 1s - loss: 7.8110e-05 - mae: 0.0068 - mape: 1.3216 - val_loss: 0.0028 - val_mae: 0.0413 - val_mape: 7.1876
# Epoch 48/200
#
# Epoch 00048: val_loss did not improve from 0.00259
# 6/6 - 1s - loss: 1.2215e-04 - mae: 0.0088 - mape: 1.6816 - val_loss: 0.0028 - val_mae: 0.0413 - val_mape: 7.1825
# Epoch 49/200
#
# Epoch 00049: val_loss improved from 0.00259 to 0.00242, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 2s - loss: 1.0757e-04 - mae: 0.0082 - mape: 1.5779 - val_loss: 0.0024 - val_mae: 0.0381 - val_mape: 6.6772
# Epoch 50/200
#
# Epoch 00050: val_loss improved from 0.00242 to 0.00240, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 2s - loss: 1.0019e-04 - mae: 0.0077 - mape: 1.4916 - val_loss: 0.0024 - val_mae: 0.0380 - val_mape: 6.6658
# Epoch 51/200
#
# Epoch 00051: val_loss did not improve from 0.00240
# 6/6 - 1s - loss: 9.0337e-05 - mae: 0.0074 - mape: 1.4405 - val_loss: 0.0027 - val_mae: 0.0410 - val_mape: 7.1177
# Epoch 52/200
#
# Epoch 00052: val_loss improved from 0.00240 to 0.00225, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 2s - loss: 1.2310e-04 - mae: 0.0089 - mape: 1.7032 - val_loss: 0.0023 - val_mae: 0.0368 - val_mape: 6.4599
# Epoch 53/200
#
# Epoch 00053: val_loss did not improve from 0.00225
# 6/6 - 1s - loss: 1.0063e-04 - mae: 0.0077 - mape: 1.4785 - val_loss: 0.0024 - val_mae: 0.0385 - val_mape: 6.7132
# Epoch 54/200
#
# Epoch 00054: val_loss did not improve from 0.00225
# 6/6 - 1s - loss: 7.5825e-05 - mae: 0.0066 - mape: 1.2985 - val_loss: 0.0024 - val_mae: 0.0378 - val_mape: 6.6057
# Epoch 55/200
#
# Epoch 00055: val_loss improved from 0.00225 to 0.00218, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 2s - loss: 6.8776e-05 - mae: 0.0063 - mape: 1.2447 - val_loss: 0.0022 - val_mae: 0.0363 - val_mape: 6.3769
# Epoch 56/200
#
# Epoch 00056: val_loss did not improve from 0.00218
# 6/6 - 1s - loss: 5.7473e-05 - mae: 0.0057 - mape: 1.1421 - val_loss: 0.0023 - val_mae: 0.0372 - val_mape: 6.4915
# Epoch 57/200
#
# Epoch 00057: val_loss improved from 0.00218 to 0.00211, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 2s - loss: 5.6005e-05 - mae: 0.0058 - mape: 1.1297 - val_loss: 0.0021 - val_mae: 0.0356 - val_mape: 6.2635
# Epoch 58/200
#
# Epoch 00058: val_loss did not improve from 0.00211
# 6/6 - 1s - loss: 5.0771e-05 - mae: 0.0054 - mape: 1.0826 - val_loss: 0.0023 - val_mae: 0.0378 - val_mape: 6.5726
# Epoch 59/200
#
# Epoch 00059: val_loss did not improve from 0.00211
# 6/6 - 1s - loss: 7.1914e-05 - mae: 0.0065 - mape: 1.2412 - val_loss: 0.0023 - val_mae: 0.0375 - val_mape: 6.5187
# Epoch 60/200
#
# Epoch 00060: val_loss improved from 0.00211 to 0.00197, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 2s - loss: 8.5527e-05 - mae: 0.0074 - mape: 1.4279 - val_loss: 0.0020 - val_mae: 0.0345 - val_mape: 6.0819
# Epoch 61/200
#
# Epoch 00061: val_loss did not improve from 0.00197
# 6/6 - 1s - loss: 8.5627e-05 - mae: 0.0073 - mape: 1.4064 - val_loss: 0.0020 - val_mae: 0.0352 - val_mape: 6.1539
# Epoch 62/200
#
# Epoch 00062: val_loss did not improve from 0.00197
# 6/6 - 1s - loss: 6.4782e-05 - mae: 0.0061 - mape: 1.1770 - val_loss: 0.0020 - val_mae: 0.0349 - val_mape: 6.0980
# Epoch 63/200
#
# Epoch 00063: val_loss improved from 0.00197 to 0.00182, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 2s - loss: 4.8703e-05 - mae: 0.0053 - mape: 1.0450 - val_loss: 0.0018 - val_mae: 0.0330 - val_mape: 5.8186
# Epoch 64/200
#
# Epoch 00064: val_loss did not improve from 0.00182
# 6/6 - 1s - loss: 4.9957e-05 - mae: 0.0053 - mape: 1.0316 - val_loss: 0.0018 - val_mae: 0.0332 - val_mape: 5.8112
# Epoch 65/200
#
# Epoch 00065: val_loss improved from 0.00182 to 0.00177, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 2s - loss: 3.8526e-05 - mae: 0.0047 - mape: 0.9339 - val_loss: 0.0018 - val_mae: 0.0326 - val_mape: 5.7342
# Epoch 66/200
#
# Epoch 00066: val_loss did not improve from 0.00177
# 6/6 - 1s - loss: 4.6499e-05 - mae: 0.0053 - mape: 1.0260 - val_loss: 0.0018 - val_mae: 0.0329 - val_mape: 5.7869
# Epoch 67/200
#
# Epoch 00067: val_loss improved from 0.00177 to 0.00164, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 2s - loss: 3.4616e-05 - mae: 0.0045 - mape: 0.8844 - val_loss: 0.0016 - val_mae: 0.0314 - val_mape: 5.5539
# Epoch 68/200
#
# Epoch 00068: val_loss did not improve from 0.00164
# 6/6 - 1s - loss: 3.4423e-05 - mae: 0.0045 - mape: 0.8948 - val_loss: 0.0017 - val_mae: 0.0323 - val_mape: 5.6513
# Epoch 69/200
#
# Epoch 00069: val_loss did not improve from 0.00164
# 6/6 - 1s - loss: 3.9155e-05 - mae: 0.0047 - mape: 0.9117 - val_loss: 0.0019 - val_mae: 0.0339 - val_mape: 5.8967
# Epoch 70/200
#
# Epoch 00070: val_loss improved from 0.00164 to 0.00158, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 2s - loss: 6.4458e-05 - mae: 0.0064 - mape: 1.2218 - val_loss: 0.0016 - val_mae: 0.0309 - val_mape: 5.4478
# Epoch 71/200
#
# Epoch 00071: val_loss did not improve from 0.00158
# 6/6 - 1s - loss: 4.4991e-05 - mae: 0.0052 - mape: 1.0253 - val_loss: 0.0017 - val_mae: 0.0321 - val_mape: 5.6372
# Epoch 72/200
#
# Epoch 00072: val_loss did not improve from 0.00158
# 6/6 - 1s - loss: 3.6329e-05 - mae: 0.0046 - mape: 0.9118 - val_loss: 0.0017 - val_mae: 0.0321 - val_mape: 5.6367
# Epoch 73/200
#
# Epoch 00073: val_loss did not improve from 0.00158
# 6/6 - 1s - loss: 2.9535e-05 - mae: 0.0041 - mape: 0.8106 - val_loss: 0.0016 - val_mae: 0.0312 - val_mape: 5.4787
# Epoch 74/200
#
# Epoch 00074: val_loss did not improve from 0.00158
# 6/6 - 1s - loss: 2.5950e-05 - mae: 0.0038 - mape: 0.7568 - val_loss: 0.0016 - val_mae: 0.0310 - val_mape: 5.4270
# Epoch 75/200
#
# Epoch 00075: val_loss did not improve from 0.00158
# 6/6 - 1s - loss: 2.7034e-05 - mae: 0.0039 - mape: 0.7744 - val_loss: 0.0016 - val_mae: 0.0312 - val_mape: 5.4668
# Epoch 76/200
#
# Epoch 00076: val_loss did not improve from 0.00158
# 6/6 - 1s - loss: 3.2320e-05 - mae: 0.0043 - mape: 0.8422 - val_loss: 0.0016 - val_mae: 0.0312 - val_mape: 5.4467
# Epoch 77/200
#
# Epoch 00077: val_loss improved from 0.00158 to 0.00146, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 2s - loss: 3.6875e-05 - mae: 0.0048 - mape: 0.9333 - val_loss: 0.0015 - val_mae: 0.0294 - val_mape: 5.2005
# Epoch 78/200
#
# Epoch 00078: val_loss did not improve from 0.00146
# 6/6 - 1s - loss: 3.7348e-05 - mae: 0.0048 - mape: 0.9181 - val_loss: 0.0015 - val_mae: 0.0296 - val_mape: 5.2054
# Epoch 79/200
#
# Epoch 00079: val_loss did not improve from 0.00146
# 6/6 - 1s - loss: 3.3499e-05 - mae: 0.0044 - mape: 0.8436 - val_loss: 0.0015 - val_mae: 0.0301 - val_mape: 5.2805
# Epoch 80/200
#
# Epoch 00080: val_loss improved from 0.00146 to 0.00138, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 2s - loss: 3.1877e-05 - mae: 0.0044 - mape: 0.8598 - val_loss: 0.0014 - val_mae: 0.0284 - val_mape: 5.0285
# Epoch 81/200
#
# Epoch 00081: val_loss did not improve from 0.00138
# 6/6 - 1s - loss: 2.8485e-05 - mae: 0.0041 - mape: 0.8046 - val_loss: 0.0015 - val_mae: 0.0304 - val_mape: 5.3148
# Epoch 82/200
#
# Epoch 00082: val_loss improved from 0.00138 to 0.00130, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 2s - loss: 3.4597e-05 - mae: 0.0046 - mape: 0.8692 - val_loss: 0.0013 - val_mae: 0.0279 - val_mape: 4.9507
# Epoch 83/200
#
# Epoch 00083: val_loss did not improve from 0.00130
# 6/6 - 1s - loss: 2.3715e-05 - mae: 0.0037 - mape: 0.7266 - val_loss: 0.0014 - val_mae: 0.0285 - val_mape: 5.0133
# Epoch 84/200
#
# Epoch 00084: val_loss did not improve from 0.00130
# 6/6 - 1s - loss: 3.3637e-05 - mae: 0.0043 - mape: 0.8678 - val_loss: 0.0015 - val_mae: 0.0296 - val_mape: 5.1886
# Epoch 85/200
#
# Epoch 00085: val_loss improved from 0.00130 to 0.00129, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 2s - loss: 2.7952e-05 - mae: 0.0041 - mape: 0.7996 - val_loss: 0.0013 - val_mae: 0.0277 - val_mape: 4.8911
# Epoch 86/200
#
# Epoch 00086: val_loss did not improve from 0.00129
# 6/6 - 1s - loss: 3.3410e-05 - mae: 0.0044 - mape: 0.8391 - val_loss: 0.0013 - val_mae: 0.0279 - val_mape: 4.9225
# Epoch 87/200
#
# Epoch 00087: val_loss did not improve from 0.00129
# 6/6 - 1s - loss: 3.6315e-05 - mae: 0.0047 - mape: 0.9117 - val_loss: 0.0013 - val_mae: 0.0283 - val_mape: 4.9733
# Epoch 88/200
#
# Epoch 00088: val_loss improved from 0.00129 to 0.00118, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 2s - loss: 3.9782e-05 - mae: 0.0050 - mape: 0.9643 - val_loss: 0.0012 - val_mae: 0.0265 - val_mape: 4.7022
# Epoch 89/200
#
# Epoch 00089: val_loss did not improve from 0.00118
# 6/6 - 1s - loss: 5.8305e-05 - mae: 0.0062 - mape: 1.1737 - val_loss: 0.0013 - val_mae: 0.0280 - val_mape: 4.9277
# Epoch 90/200
#
# Epoch 00090: val_loss did not improve from 0.00118
# 6/6 - 1s - loss: 4.7318e-05 - mae: 0.0055 - mape: 1.0417 - val_loss: 0.0012 - val_mae: 0.0269 - val_mape: 4.7693
# Epoch 91/200
#
# Epoch 00091: val_loss improved from 0.00118 to 0.00116, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 2s - loss: 5.2443e-05 - mae: 0.0056 - mape: 1.0643 - val_loss: 0.0012 - val_mae: 0.0263 - val_mape: 4.6629
# Epoch 92/200
#
# Epoch 00092: val_loss did not improve from 0.00116
# 6/6 - 1s - loss: 3.1899e-05 - mae: 0.0043 - mape: 0.8428 - val_loss: 0.0013 - val_mae: 0.0274 - val_mape: 4.8100
# Epoch 93/200
#
# Epoch 00093: val_loss improved from 0.00116 to 0.00107, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 2s - loss: 4.5490e-05 - mae: 0.0053 - mape: 1.0297 - val_loss: 0.0011 - val_mae: 0.0252 - val_mape: 4.5046
# Epoch 94/200
#
# Epoch 00094: val_loss did not improve from 0.00107
# 6/6 - 1s - loss: 3.4402e-05 - mae: 0.0046 - mape: 0.8779 - val_loss: 0.0012 - val_mae: 0.0261 - val_mape: 4.6173
# Epoch 95/200
#
# Epoch 00095: val_loss did not improve from 0.00107
# 6/6 - 1s - loss: 2.7003e-05 - mae: 0.0039 - mape: 0.7724 - val_loss: 0.0012 - val_mae: 0.0264 - val_mape: 4.6698
# Epoch 96/200
#
# Epoch 00096: val_loss did not improve from 0.00107
# 6/6 - 1s - loss: 2.4303e-05 - mae: 0.0037 - mape: 0.7175 - val_loss: 0.0011 - val_mae: 0.0254 - val_mape: 4.5144
# Epoch 97/200
#
# Epoch 00097: val_loss did not improve from 0.00107
# 6/6 - 1s - loss: 2.8441e-05 - mae: 0.0042 - mape: 0.8137 - val_loss: 0.0012 - val_mae: 0.0262 - val_mape: 4.6246
# Epoch 98/200
#
# Epoch 00098: val_loss did not improve from 0.00107
# 6/6 - 1s - loss: 2.7322e-05 - mae: 0.0041 - mape: 0.7805 - val_loss: 0.0011 - val_mae: 0.0256 - val_mape: 4.5516
# Epoch 99/200
#
# Epoch 00099: val_loss improved from 0.00107 to 0.00104, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 2s - loss: 2.9643e-05 - mae: 0.0042 - mape: 0.8205 - val_loss: 0.0010 - val_mae: 0.0248 - val_mape: 4.4270
# Epoch 100/200
#
# Epoch 00100: val_loss did not improve from 0.00104
# 6/6 - 1s - loss: 2.7109e-05 - mae: 0.0041 - mape: 0.7859 - val_loss: 0.0011 - val_mae: 0.0257 - val_mape: 4.5498
# Epoch 101/200
#
# Epoch 00101: val_loss improved from 0.00104 to 0.00104, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 2s - loss: 3.6109e-05 - mae: 0.0046 - mape: 0.8697 - val_loss: 0.0010 - val_mae: 0.0248 - val_mape: 4.4260
# Epoch 102/200
#
# Epoch 00102: val_loss did not improve from 0.00104
# 6/6 - 1s - loss: 2.5179e-05 - mae: 0.0037 - mape: 0.7162 - val_loss: 0.0011 - val_mae: 0.0251 - val_mape: 4.4845
# Epoch 103/200
#
# Epoch 00103: val_loss did not improve from 0.00104
# 6/6 - 1s - loss: 2.5779e-05 - mae: 0.0037 - mape: 0.7144 - val_loss: 0.0010 - val_mae: 0.0249 - val_mape: 4.4451
# Epoch 104/200
#
# Epoch 00104: val_loss did not improve from 0.00104
# 6/6 - 1s - loss: 3.0318e-05 - mae: 0.0042 - mape: 0.8198 - val_loss: 0.0011 - val_mae: 0.0251 - val_mape: 4.4874
# Epoch 105/200
#
# Epoch 00105: val_loss did not improve from 0.00104
# 6/6 - 1s - loss: 3.2052e-05 - mae: 0.0043 - mape: 0.8247 - val_loss: 0.0011 - val_mae: 0.0254 - val_mape: 4.5321
# Epoch 106/200
#
# Epoch 00106: val_loss improved from 0.00104 to 0.00099, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 2s - loss: 3.2723e-05 - mae: 0.0043 - mape: 0.8141 - val_loss: 9.9282e-04 - val_mae: 0.0241 - val_mape: 4.3100
# Epoch 107/200
#
# Epoch 00107: val_loss did not improve from 0.00099
# 6/6 - 1s - loss: 2.5969e-05 - mae: 0.0039 - mape: 0.7555 - val_loss: 0.0010 - val_mae: 0.0247 - val_mape: 4.4108
# Epoch 108/200
#
# Epoch 00108: val_loss did not improve from 0.00099
# 6/6 - 1s - loss: 2.4929e-05 - mae: 0.0038 - mape: 0.7193 - val_loss: 0.0010 - val_mae: 0.0247 - val_mape: 4.4195
# Epoch 109/200
#
# Epoch 00109: val_loss did not improve from 0.00099
# 6/6 - 1s - loss: 3.2916e-05 - mae: 0.0044 - mape: 0.8470 - val_loss: 0.0010 - val_mae: 0.0246 - val_mape: 4.3888
# Epoch 110/200
#
# Epoch 00110: val_loss did not improve from 0.00099
# 6/6 - 1s - loss: 2.6222e-05 - mae: 0.0039 - mape: 0.7447 - val_loss: 0.0010 - val_mae: 0.0246 - val_mape: 4.4091
# Epoch 111/200
#
# Epoch 00111: val_loss did not improve from 0.00099
# 6/6 - 1s - loss: 2.4713e-05 - mae: 0.0037 - mape: 0.7083 - val_loss: 0.0011 - val_mae: 0.0255 - val_mape: 4.5346
# Epoch 112/200
#
# Epoch 00112: val_loss improved from 0.00099 to 0.00098, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 2s - loss: 3.6509e-05 - mae: 0.0050 - mape: 0.9451 - val_loss: 9.7567e-04 - val_mae: 0.0239 - val_mape: 4.3066
# Epoch 113/200
#
# Epoch 00113: val_loss improved from 0.00098 to 0.00095, saving model to CNN+Bi-LSTM.hdf5
# 6/6 - 2s - loss: 2.7937e-05 - mae: 0.0041 - mape: 0.7865 - val_loss: 9.5069e-04 - val_mae: 0.0236 - val_mape: 4.2421
# Epoch 114/200
#
# Epoch 00114: val_loss did not improve from 0
# Epoch 192/200
#
# Epoch 00192: val_loss did not improve from 0.00080
# 6/6 - 1s - loss: 1.1257e-05 - mae: 0.0026 - mape: 0.4911 - val_loss: 8.2048e-04 - val_mae: 0.0216 - val_mape: 3.9277
# Epoch 193/200
#
# Epoch 00193: val_loss did not improve from 0.00080
# 6/6 - 1s - loss: 1.0681e-05 - mae: 0.0025 - mape: 0.4804 - val_loss: 8.3934e-04 - val_mae: 0.0219 - val_mape: 3.9670
# Epoch 194/200
#
# Epoch 00194: val_loss did not improve from 0.00080
# 6/6 - 1s - loss: 1.0830e-05 - mae: 0.0026 - mape: 0.4858 - val_loss: 8.2682e-04 - val_mae: 0.0218 - val_mape: 3.9523
# Epoch 195/200
#
# Epoch 00195: val_loss did not improve from 0.00080
# 6/6 - 1s - loss: 8.0831e-06 - mae: 0.0022 - mape: 0.4172 - val_loss: 8.3164e-04 - val_mae: 0.0218 - val_mape: 3.9545
# Epoch 196/200
#
# Epoch 00196: val_loss did not improve from 0.00080
# 6/6 - 1s - loss: 1.0010e-05 - mae: 0.0024 - mape: 0.4577 - val_loss: 8.0738e-04 - val_mae: 0.0215 - val_mape: 3.9097
# Epoch 197/200
#
# Epoch 00197: val_loss did not improve from 0.00080
# 6/6 - 1s - loss: 9.9926e-06 - mae: 0.0024 - mape: 0.4677 - val_loss: 8.3198e-04 - val_mae: 0.0218 - val_mape: 3.9465
# Epoch 198/200
#
# Epoch 00198: val_loss did not improve from 0.00080
# 6/6 - 1s - loss: 1.1835e-05 - mae: 0.0026 - mape: 0.5008 - val_loss: 8.4551e-04 - val_mae: 0.0221 - val_mape: 3.9999
# Epoch 199/200
#
# Epoch 00199: val_loss did not improve from 0.00080
# 6/6 - 1s - loss: 1.0802e-05 - mae: 0.0025 - mape: 0.4807 - val_loss: 8.2646e-04 - val_mae: 0.0218 - val_mape: 3.9595
# Epoch 200/200
#
# Epoch 00200: val_loss did not improve from 0.00080
# 6/6 - 1s - loss: 1.2596e-05 - mae: 0.0027 - mape: 0.5145 - val_loss: 8.2872e-04 - val_mae: 0.0218 - val_mape: 3.9511
#
# Evaluation metrics
# Training Data - Loss: 0.0001, MAE: 0.0062, MAPE: 1.1854
# Validation Data - Loss: 0.0008, MAE: 0.0213, MAPE: 3.8731
# Test Data - Loss: 0.0018, MAE: 0.0292, MAPE: 6.2077

# %% [markdown]
# ## **Conculsion 2**
#
# As expected applying a moving average to the price data smoothed the return distribution and thus lead to an improved model performance.
#
# However, when applying a moving average effect to a time series your dataset represent the real market less accurately. Subsequently, your dataset is biased towards less outliers.
#
# When investing in the stock market it is curcial that outliers are not excluded or smoothed out since outliers majorly contribute to your trading performance.
#
# Thus, any data transformations that can't be easily reverted once the predictions have been made, should be avoided.
#
# Nevertheless, seeing that a slight smoothing of the time series improved the error rates substantially for the Bi-LSTM model is a good thing to consider for future work.
#
# In conculsion, I'll be looking for other prediction indicators which will be adding to the model's performance.
#
# *Next up are financial news...*
#
#
# ##### **Moving Average Bi-LSTM**
# > Validation Data --> Loss: `0.0005`, MAE: `0.0170`, MAPE: `3.0885`
#
# > Test Data --> Loss: `0.0009`, MAE: `0.0201`, MAPE: `4.0887`
#
# ##### **Bi-LSTM**
# >Validation Data --> Loss: `0.0009`, MAE: `0.0211`, MAPE: `3.5828`
#
# >Test Data --> Loss: `0.0014`, MAE: `0.0245`, MAPE: `4.2656`
#
# ---
# ---
#
# ##### **Moving Average CNN+Bi-LSTM**
# >Validation Data --> Loss: `0.0008`, MAE: `0.0213`, MAPE: `3.8731`
#
# >Test Data --> Loss: `0.0018`, MAE: `0.0292`, MAPE: `6.2077`
#
# ##### **CNN+Bi-LSTM**
# >Validation Data --> Loss: `0.0010`, MAE: `0.0229`, MAPE: `3.8454`
#
# >Test Data --> Loss: `0.0015`, MAE: `0.0264`, MAPE: `4.5289`
